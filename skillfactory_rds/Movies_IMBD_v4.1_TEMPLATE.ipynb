# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
data = pd.read_csv('movie_bd_v5.csv')
data.sample(5)
# Out:
#         imdb_id    budget    revenue                   original_title  \
# 34    tt3170832   6000000   35401758                             Room
# 477   tt1027718  70000000  134748021  Wall Street: Money Never Sleeps
# 1460  tt0454945  20000000   33889159                    She's the Man
# 365   tt1142433  15000000    6405245                        Post Grad
# 1174  tt0318283  30000000   15368897                      Alex & Emma
#
#                                                    cast          director  \
# 34    Brie Larson|Jacob Tremblay|Joan Allen|Sean Bri...  Lenny Abrahamson
# 477   Michael Douglas|Shia LaBeouf|Josh Brolin|Carey...      Oliver Stone
# 1460  Amanda Bynes|Channing Tatum|Laura Ramsey|Vinni...      Andy Fickman
# 365   Alexis Bledel|Zach Gilford|Rodrigo Santoro|Jan...      Vicky Jenson
# 1174  Luke Wilson|Kate Hudson|Sophie Marceau|David P...        Rob Reiner
#
#                                                 tagline  \
# 34                             Love knows no boundaries
# 477                              Gordon never gives up.
# 1460  If you wanna chase your dream, sometimes you g...
# 365                                  A Pre-Life Crisis.
# 1174   Is it love... or are they just imagining things?
#
#                                                overview  runtime  \
# 34    Jack is a young boy of 5 years old who has liv...      117
# 477   As the global economy teeters on the brink of ...      133
# 1460  Viola Johnson is in a real jam. Complications ...      105
# 365   Ryden Malby has a master plan. Graduate colleg...       89
# 1174  Writer Alex Sheldon (Luke Wilson) must finish ...       96
#
#                            genres  \
# 34                 Drama|Thriller
# 477                   Drama|Crime
# 1460  Comedy|Drama|Family|Romance
# 365                        Comedy
# 1174               Comedy|Romance
#
#                                    production_companies release_date  \
# 34    Element Pictures|No Trace Camping|A24|Duperele...   10/16/2015
# 477   Twentieth Century Fox Film Corporation|Dune En...     9/2/2010
# 1460             DreamWorks SKG|Lakeshore Entertainment    3/17/2006
# 365   Dune Entertainment|Cold Spring Pictures|The Mo...    8/21/2009
# 1174  Epsilon Motion Pictures|Franchise Pictures|Esc...    6/16/2003
#
#       vote_average  release_year
# 34             8.0          2015
# 477            5.8          2010
# 1460           6.3          2006
# 365            5.1          2009
# 1174           5.0          2003

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

# тут другие ваши предобработки колонок например:

#the time given in the dataset is in string format.
#So we need to change this in datetime format
# ...profit = revenue - budget
data['profit']=data['revenue']-data['budget']
data['month']=pd.to_datetime(data['release_date']).dt.month
data['title_length'] = data['original_title'].map(lambda x: len(x))
data['words_overview'] = data['overview'].map(lambda x: len(x.split(' ')))

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
# в словарь вставляем номер вопроса и ваш ответ на него
# Пример: 
answers['1'] = '2. Spider-Man 3 (tt0413300)'
# запишите свой вариант ответа
answers['1'] = '5. Pirates of the Caribbean: On Stranger Tides (tt1298650)' #+
# если ответили верно, можете добавить комментарий со значком "+"

# %%
# тут пишем ваш код для решения данного вопроса:
data[(data['budget'] == data['budget'].max())]
# Out:
#        imdb_id     budget     revenue  \
# 723  tt1298650  380000000  1021683000
#
#                                   original_title  \
# 723  Pirates of the Caribbean: On Stranger Tides
#
#                                                   cast      director  \
# 723  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...  Rob Marshall
#
#                          tagline  \
# 723  Live Forever Or Die Trying.
#
#                                               overview  runtime  \
# 723  Captain Jack Sparrow crosses paths with a woma...      136
#
#                        genres  \
# 723  Adventure|Action|Fantasy
#
#                                   production_companies release_date  \
# 723  Walt Disney Pictures|Jerry Bruckheimer Films|M...    5/11/2011
#
#      vote_average  release_year     profit  month  title_length  \
# 723           6.3          2011  641683000      5            43
#
#      words_overview
# 723              75

# %% [markdown]
# ВАРИАНТ 2

# %%
# можно добавлять разные варианты решения
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year  \
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000
#
#              profit        month  title_length  words_overview
# count  1.889000e+03  1889.000000   1889.000000     1889.000000
# mean   1.010545e+08     6.933298     15.037057       52.410270
# std    1.830733e+08     3.390196      8.552660       26.631917
# min   -1.657101e+08     1.000000      1.000000       10.000000
# 25%    5.000000e+06     4.000000      9.000000       32.000000
# 50%    4.400041e+07     7.000000     13.000000       48.000000
# 75%    1.201842e+08    10.000000     18.000000       67.000000
# max    2.544506e+09    12.000000     83.000000      175.000000

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
# думаю логику работы с этим словарем вы уже поняли, 
# по этому не буду больше его дублировать

answers['2'] = '2. Gods and Generals (tt0279111)' #+

# %%
data[(data['runtime'] == data['runtime'].max())]
# Out:
#         imdb_id    budget   revenue     original_title  \
# 1157  tt0279111  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1157  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1157  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1157  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1157  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_average  release_year    profit  month  title_length  \
# 1157           5.8          2003 -43076064      2            17
#
#       words_overview
# 1157              48

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
answers['3'] ='3. Winnie the Pooh (tt1449283)' #+

data[(data['runtime'] == data['runtime'].min())]
# Out:
#        imdb_id    budget   revenue   original_title  \
# 768  tt1449283  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 768  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 768  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 768  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 768  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_average  release_year    profit  month  title_length  \
# 768    4/13/2011           6.8          2011 -15540000      4            15
#
#      words_overview
# 768              52

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
answers['4']='2. 110' #+
data['runtime'].mean()

# кроме этого после применения data.describe() можно увидеть среднюю длительность фильма 
# и медианное значение длительности тоже :)
# Out:
# 109.6585494970884

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
answers['5']='1. 107' #+
data['runtime'].median()
# Out:
# 107.0

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
# лучше код получения столбца profit вынести в Предобработку что в начале

answers['6']='5. Avatar (tt0499549)'  #+

data[(data['profit'] == data['profit'].max())]
# Out:
#        imdb_id     budget     revenue original_title  \
# 239  tt0499549  237000000  2781505847         Avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  \
# 239  Action|Adventure|Fantasy|Science Fiction
#
#                                   production_companies release_date  \
# 239  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
#
#      vote_average  release_year      profit  month  title_length  \
# 239           7.1          2009  2544505847     12             6
#
#      words_overview
# 239              28

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
answers['7']='5. The Lone Ranger (tt1210819)' #+
data[(data['profit'] == data['profit'].min())]
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year     profit  month  title_length  \
# 1245           6.0          2013 -165710090      7            15
#
#       words_overview
# 1245              68

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
answers['8']='1. 1478' #+

len(data[(data['profit'] > 0)])
# Out:
# 1478

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
answers['9']='4. The Dark Knight (tt0468569)' #+
data[(data['profit']==data[(data['release_year'] == 2008)]['profit'].max()) & (data['release_year'] == 2008)]
# Out:
#        imdb_id     budget     revenue   original_title  \
# 599  tt0468569  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 599  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 599      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 599  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_average  release_year     profit  month  title_length  \
# 599           8.1          2008  816921825      7            15
#
#      words_overview
# 599              67

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
answers['10']='5. The Lone Ranger (tt1210819)' #+

data[(data['release_year'] >= 2012) & (data['release_year'] <= 2014) & (data['profit'] == data.query('2012 <= release_year <= 2014 ')['profit'].min() )]
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year     profit  month  title_length  \
# 1245           6.0          2013 -165710090      7            15
#
#       words_overview
# 1245              68

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
# эту задачу тоже можно решать разными подходами, попробуй реализовать разные варианты
# если будешь добавлять функцию - выноси ее в предобработку что в начале
answers['11']='3. Drama' #+

gnrs = Counter()
for x in data.genres.str.split('|'):
    gnrs += Counter(x)
gnrs.most_common(1)
# Out:
# [('Drama', 782)]

# %% [markdown]
# ВАРИАНТ 2

# %%
answers['11']='3. Drama' #+

gen_list=[]
for x in data.genres.str.split('|'):
    gen_list.extend(x)
df = pd.DataFrame(gen_list,columns =['genr'])
df['genr'].value_counts()
# Out:
# Drama              782
# Comedy             683
# Thriller           596
# Action             582
# Adventure          415
# Crime              315
# Romance            308
# Family             260
# Science Fiction    248
# Fantasy            222
# Horror             176
# Mystery            168
# Animation          139
# Music               64
# History             62
# War                 58
# Western             19
# Documentary          8
# Foreign              2
# Name: genr, dtype: int64

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
answers['12']='1. Drama' #+
gnrs = Counter()
for x in data[data['profit'] > 0].genres.str.split('|'):
    gnrs += Counter(x)
gnrs.most_common(1)
# Out:
# [('Drama', 560)]

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сборы?

# %%
answers['13']='5. Peter Jackson' #+

data.groupby(['director']).sum().sort_values(by='revenue',ascending=False)
# Out:
#                        budget     revenue  runtime  vote_average  \
# director
# Peter Jackson      1288000000  6490593685     1355          58.1
# Christopher Nolan  1005000000  4167548502     1135          61.1
# David Yates         775000000  4154295625      567          29.6
# Michael Bay        1126000000  3886938960     1209          50.0
# J.J. Abrams         740000000  3579169916      633          35.1
# ...                       ...         ...      ...           ...
# David MichÃ´d        12250000     2295423      100           6.0
# Steven Shainberg     16800000     2281089      122           6.3
# Paul Schrader         7000000     2062066      104           5.9
# Keanu Reeves         25000000     2054941      105           5.6
# Simon Hunter          8000000     2033165      111           5.1
#
#                    release_year      profit  month  title_length  \
# director
# Peter Jackson             16059  5202593685     95           265
# Christopher Nolan         16057  3162548502     63            97
# David Yates                8037  3379295625     30           167
# Michael Bay               16063  2760938960     47           152
# J.J. Abrams               10054  2839169916     33            90
# ...                         ...         ...    ...           ...
# David MichÃ´d              2014    -9954577      5             9
# Steven Shainberg           2006   -14518911      8            41
# Paul Schrader              2002    -4937934     10            10
# Keanu Reeves               2013   -22945059      7            14
# Simon Hunter               2008    -5966835      8            17
#
#                    words_overview
# director
# Peter Jackson                 363
# Christopher Nolan             388
# David Yates                   177
# Michael Bay                   499
# J.J. Abrams                   313
# ...                           ...
# David MichÃ´d                  36
# Steven Shainberg               66
# Paul Schrader                  70
# Keanu Reeves                   16
# Simon Hunter                   67
#
# [957 rows x 9 columns]

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
answers['14']='3. Robert Rodriguez' #+

action = Counter()
for x in data[data['genres'].str.contains('Action')].director.str.split('|'):
    action += Counter(x)
action.most_common(1)
# Out:
# [('Robert Rodriguez', 9)]

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
answers['15']='3. Chris Hemsworth' #+

# решение получилось незатейливое
money_actors=Counter()
d_goal_year=data[(data['release_year'] == 2012)] # чтобы решение читалось нормально
for row in zip(d_goal_year['cast'],d_goal_year['revenue']): # выбираем конкретные столбцы в датасете
    #print(row)
    for actor in row[0].split('|'):
        money_actors[actor] += row[1]
sorted(money_actors.items(), key=lambda item: item[1], reverse=True)
# Out:
# [('Chris Hemsworth', 2027450773),
#  ('Denis Leary', 1629460639),
#  ('Anne Hathaway', 1522851057),
#  ('Robert Downey Jr.', 1519557910),
#  ('Chris Evans', 1519557910),
#  ('Mark Ruffalo', 1519557910),
#  ('Scarlett Johansson', 1519557910),
#  ('Ralph Fiennes', 1409561013),
#  ('Sacha Baron Cohen', 1368110577),
#  ('Kristen Stewart', 1234384318),
#  ('Emma Thompson', 1163009983),
#  ('Tom Hardy', 1134717867),
#  ('Seann William Scott', 1112234366),
#  ('Daniel Craig', 1108561013),
#  ('Judi Dench', 1108561013),
#  ('Javier Bardem', 1108561013),
#  ('Naomie Harris', 1108561013),
#  ('Josh Hutcherson', 1091710235),
#  ('Christian Bale', 1081041287),
#  ('Michael Caine', 1081041287),
#  ('Gary Oldman', 1081041287),
#  ('Ian McKellen', 1017003568),
#  ('Martin Freeman', 1017003568),
#  ('Richard Armitage', 1017003568),
#  ('Andy Serkis', 1017003568),
#  ('Cate Blanchett', 1017003568),
#  ('John Leguizamo', 914138503),
#  ('Jennifer Lawrence', 896949406),
#  ('Ray Romano', 877244782),
#  ('Chris Wedge', 877244782),
#  ('Robert Pattinson', 835063556),
#  ('Elizabeth Banks', 829566659),
#  ('Taylor Lautner', 829000000),
#  ('Peter Facinelli', 829000000),
#  ('Elizabeth Reaser', 829000000),
#  ('Rhys Ifans', 806125608),
#  ('Charlize Theron', 799770142),
#  ('Frances McDormand', 755060062),
#  ('Andrew Garfield', 752215857),
#  ('Emma Stone', 752215857),
#  ('Martin Sheen', 752215857),
#  ('Hugh Jackman', 748751440),
#  ('Ben Stiller', 746921274),
#  ('David Schwimmer', 746921274),
#  ('Chris Rock', 746921274),
#  ('Tommy Lee Jones', 738307827),
#  ('Woody Harrelson', 710632953),
#  ('Liam Hemsworth', 691210692),
#  ('Liam Neeson', 677141306),
#  ('Taylor Kitsch', 634164585),
#  ('Will Smith', 624026776),
#  ('Josh Brolin', 624026776),
#  ('Michael Stuhlbarg', 624026776),
#  ('Mark Wahlberg', 612468315),
#  ('Giovanni Ribisi', 612468315),
#  ('Suraj Sharma', 609016565),
#  ('Irrfan Khan', 609016565),
#  ('Ayush Tandon', 609016565),
#  ('Gautam Belur', 609016565),
#  ('Adil Hussain', 609016565),
#  ('Billy Connolly', 598503505),
#  ('Channing Tatum', 598294075),
#  ('Mila Kunis', 549368315),
#  ('Seth MacFarlane', 549368315),
#  ('Joel McHale', 549368315),
#  ('Bryan Cranston', 540910192),
#  ('Kelly Macdonald', 538983207),
#  ('Julie Walters', 538983207),
#  ('Kevin McKidd', 538983207),
#  ('Jane Lynch', 526042190),
#  ('Rosamund Pike', 519340595),
#  ('Guy Pearce', 489050752),
#  ('John C. Reilly', 471222889),
#  ('Sarah Silverman', 471222889),
#  ('Jack McBrayer', 471222889),
#  ('Jamie Elman', 471222889),
#  ('Bruce Willis', 449378341),
#  ('Kerry Washington', 447412515),
#  ('Russell Crowe', 441809770),
#  ('Amanda Seyfried', 441809770),
#  ('Michael Fassbender', 436542748),
#  ('Jamie Foxx', 425368238),
#  ('Christoph Waltz', 425368238),
#  ('Leonardo DiCaprio', 425368238),
#  ('Samuel L. Jackson', 425368238),
#  ('Mark Strong', 416959816),
#  ('Adam Sandler', 416433970),
#  ('CiarÃ¡n Hinds', 411869836),
#  ('Maggie Grace', 408345336),
#  ('Noomi Rapace', 403170142),
#  ('Idris Elba', 403170142),
#  ('Sam Claflin', 396600000),
#  ('Ian McShane', 396600000),
#  ('Kate Beckinsale', 394302074),
#  ('Brooklyn Decker', 382725485),
#  ('Famke Janssen', 376141306),
#  ('Rade Serbedzija', 376141306),
#  ('Luke Grimes', 376141306),
#  ('Alec Baldwin', 366360283),
#  ('Steve Buscemi', 358375603),
#  ('David Spade', 358375603),
#  ('Kevin James', 358375603),
#  ('Selena Gomez', 358375603),
#  ('Brendan Gleeson', 356072317),
#  ('Dwayne Johnson', 355692760),
#  ('Kristin Davis', 355692760),
#  ('Vanessa Hudgens', 355692760),
#  ('Luis GuzmÃ¡n', 355692760),
#  ('Jason Statham', 352919609),
#  ('Anna Kendrick', 350316209),
#  ('Zac Efron', 348840316),
#  ('Danny DeVito', 348840316),
#  ('Taylor Swift', 348840316),
#  ('Ed Helms', 348840316),
#  ('Rob Riggle', 348840316),
#  ('Sam Worthington', 347221189),
#  ('Edward Norton', 344836104),
#  ('Chris Pine', 319376448),
#  ('Sylvester Stallone', 312573423),
#  ('Dolph Lundgren', 312573423),
#  ('Arnold Schwarzenegger', 312573423),
#  ('Jude Law', 306941670),
#  ('Isla Fisher', 306941670),
#  ('Alexander SkarsgÃ¥rd', 303025485),
#  ('Rihanna', 303025485),
#  ('Tadanobu Asano', 303025485),
#  ('Edgar RamÃ\xadrez', 301000000),
#  ('Lynn Collins', 284139100),
#  ('Willem Dafoe', 284139100),
#  ('Tom Cruise', 277759208),
#  ('Jeremy Renner', 276572938),
#  ('Rachel Weisz', 276572938),
#  ('Scott Glenn', 276572938),
#  ('Stacy Keach', 276572938),
#  ('David Oyelowo', 268705972),
#  ('Megan Fox', 267438319),
#  ('Michelle Pfeiffer', 257961927),
#  ('Johnny Depp', 245527149),
#  ('Helena Bonham Carter', 245527149),
#  ('Jackie Earle Haley', 245527149),
#  ('Jonny Lee Miller', 245527149),
#  ('Milla Jovovich', 240159255),
#  ('Sienna Guillory', 240159255),
#  ('Michelle Rodriguez', 240159255),
#  ('Aryana Engineer', 240159255),
#  ('Li Bingbing', 240159255),
#  ('Jason Biggs', 234989584),
#  ('Alyson Hannigan', 234989584),
#  ('Chris Klein', 234989584),
#  ('Thomas Ian Nicholas', 234989584),
#  ('Ben Affleck', 232324128),
#  ('Alan Arkin', 232324128),
#  ('John Goodman', 232324128),
#  ('Victor Garber', 232324128),
#  ('Michael Ealy', 228470507),
#  ('Bradley Cooper', 218970175),
#  ('Richard Jenkins', 218340595),
#  ('Werner Herzog', 218340595),
#  ('Colin Farrell', 218224335),
#  ('Ewan McGregor', 213646729),
#  ('Denzel Washington', 208076205),
#  ('Ryan Reynolds', 208076205),
#  ('Vera Farmiga', 208076205),
#  ('Joel Kinnaman', 208076205),
#  ('Robert De Niro', 205738714),
#  ('Jacki Weaver', 205738714),
#  ('Chris Tucker', 205738714),
#  ('Jonah Hill', 201585328),
#  ('Brie Larson', 201585328),
#  ('Dave Franco', 201585328),
#  ('Ellie Kemper', 201585328),
#  ('Jessica Biel', 198802074),
#  ('Bill Nighy', 198802074),
#  ('Rachel McAdams', 196114570),
#  ('Sam Neill', 196114570),
#  ('Scott Speedman', 196114570),
#  ('Jessica Lange', 196114570),
#  ('Chris Pratt', 186730467),
#  ('Jessica Chastain', 186497296),
#  ('Julia Roberts', 183018522),
#  ('Lily Collins', 183018522),
#  ('Armie Hammer', 183018522),
#  ('Nathan Lane', 183018522),
#  ('Martin Klebba', 183018522),
#  ('Naomi Watts', 180274123),
#  ('Tom Holland', 180274123),
#  ('Samuel Joslin', 180274123),
#  ('Oaklee Pendergast', 180274123),
#  ('Sayed Badreya', 179379533),
#  ('Aasif Mandvi', 179379533),
#  ('Anna Faris', 179379533),
#  ('Matthew McConaughey', 167221571),
#  ('Olivia Munn', 167221571),
#  ('Cody Horn', 167221571),
#  ('Alex Pettyfer', 167221571),
#  ('Salma Hayek', 165338361),
#  ('Paul Rudd', 145618720),
#  ('Dane DeHaan', 145000000),
#  ('Alex Russell', 145000000),
#  ('Michael B. Jordan', 145000000),
#  ('Michael Kelly', 145000000),
#  ('Anna Wood', 145000000),
#  ('Katie Featherston', 142817992),
#  ('Kathryn Newton', 142817992),
#  ('Matt Shively', 142817992),
#  ('Brady Allen', 142817992),
#  ('Sprague Grayden', 142817992),
#  ('Jason Segel', 141968537),
#  ('Kathryn McCormick', 140470746),
#  ('Ryan Guzman', 140470746),
#  ('Stephen Boss', 140470746),
#  ('Megan Boone', 140470746),
#  ('Jessica Guadix', 140470746),
#  ('Jim Sturgess', 138589343),
#  ('Jason Clarke', 132820716),
#  ('Joel Edgerton', 132820716),
#  ('Stephen Rea', 132400000),
#  ('Theo James', 132400000),
#  ('India Eisley', 132400000),
#  ('Tom Hanks', 130482868),
#  ('Halle Berry', 130482868),
#  ('Jim Broadbent', 130482868),
#  ('Hugo Weaving', 130482868),
#  ('Jeffrey Dean Morgan', 130252858),
#  ('Daniel Radcliffe', 127730736),
#  ('Sidney Johnston', 127730736),
#  ('Alisa Khazanova', 127730736),
#  ('Mary Stockley', 127730736),
#  ('Billy Crystal', 119772232),
#  ('Bette Midler', 119772232),
#  ('Marisa Tomei', 119772232),
#  ('Tom Everett Scott', 119772232),
#  ('Bailee Madison', 119772232),
#  ('Hugh Grant', 118338361),
#  ('Jeremy Piven', 118338361),
#  ('Brian Blessed', 118338361),
#  ('Skylar Astin', 115350426),
#  ('Brittany Snow', 115350426),
#  ('Anna Camp', 115350426),
#  ('Rebel Wilson', 115350426),
#  ('Meryl Streep', 114281051),
#  ('Steve Carell', 114281051),
#  ('Jean Smart', 114281051),
#  ('Marin Ireland', 114281051),
#  ('Benjamin Walker', 112265139),
#  ('Dominic Cooper', 112265139),
#  ('Anthony Mackie', 112265139),
#  ('Mary Elizabeth Winstead', 112265139),
#  ('Rufus Sewell', 112265139),
#  ('Kodi Smit-McPhee', 107139399),
#  ('Tucker Albrizzi', 107139399),
#  ('Jodelle Ferland', 107139399),
#  ('Casey Affleck', 107139399),
#  ('Emily Blunt', 100951751),
#  ('Oliver Cooper', 100000000),
#  ('Jonathan Daniel Brown', 100000000),
#  ('Thomas Mann', 100000000),
#  ('Dax Flame', 100000000),
#  ('Kirby Bliss Blanton', 100000000),
#  ('Jerry Ferrara', 96070507),
#  ('Meagan Good', 96070507),
#  ('Regina Hall', 96070507),
#  ('Kevin Hart', 96070507),
#  ('Susan Sarandon', 93543423),
#  ('Leslie Mann', 88058786),
#  ('Maude Apatow', 88058786),
#  ('Natasha Calis', 85446075),
#  ('Madison Davenport', 85446075),
#  ('Kyra Sedgwick', 85446075),
#  ('Rob LaBelle', 85446075),
#  ('Charlie Tahan', 81491068),
#  ('Winona Ryder', 81491068),
#  ("Catherine O'Hara", 81491068),
#  ('Martin Short', 81491068),
#  ('Martin Landau', 81491068),
#  ('Roselyn SÃ¡nchez', 81272766),
#  ('Emilio Rivera', 81272766),
#  ('Nestor Serrano', 81272766),
#  ('Gonzalo Menendez', 81272766),
#  ('Alexander Asefa', 81272766),
#  ('Cameron Diaz', 79700000),
#  ('Jennifer Lopez', 79700000),
#  ('Joseph Gordon-Levitt', 78125599),
#  ('Devon Bostick', 77112176),
#  ('Steve Zahn', 77112176),
#  ('Peyton List', 77112176),
#  ('Rachael Harris', 77112176),
#  ('Zachary Gordon', 77112176),
#  ('Jared Gilman', 68263166),
#  ('Kara Hayward', 68263166),
#  ('Bill Murray', 68263166),
#  ('Kristen Connolly', 66486080),
#  ('Anna Hutchison', 66486080),
#  ('Fran Kranz', 66486080),
#  ('Jesse Williams', 66486080),
#  ('Ben Foster', 63100000),
#  ('J.K. Simmons', 63100000),
#  ('Maggie Smith', 59520298),
#  ('Tom Courtenay', 59520298),
#  ('Pauline Collins', 59520298),
#  ('Michael Gambon', 59520298),
#  ('Diego Boneta', 59418613),
#  ('Julianne Hough', 59418613),
#  ('Eva Amurri Martino', 58058367),
#  ('Leighton Meester', 58058367),
#  ('Andy Samberg', 58058367),
#  ('Sean Hayes', 54819301),
#  ('Will Sasso', 54819301),
#  ('Chris Diamantopoulos', 54819301),
#  ('SofÃ\xada Vergara', 54819301),
#  ('Alison Brie', 53909751),
#  ('Shia LaBeouf', 53676580),
#  ('Mia Wasikowska', 53676580),
#  ('Adelaide Clemens', 52302796),
#  ('Kit Harington', 52302796),
#  ('Sean Bean', 52302796),
#  ('Carrie-Anne Moss', 52302796),
#  ('Radha Mitchell', 52302796),
#  ('Cuba Gooding Jr.', 50365377),
#  ('Daniela Ruah', 50365377),
#  ('Terrence Howard', 50365377),
#  ('Jake Gyllenhaal', 48126384),
#  ('Michael PeÃ±a', 48126384),
#  ('Natalie Martinez', 48126384),
#  ('David Harbour', 48126384),
#  ('Paul Dano', 47042000),
#  ('Noah Segan', 47042000),
#  ('Blake Lively', 47000000),
#  ('Aaron Taylor-Johnson', 47000000),
#  ('Benicio del Toro', 47000000),
#  ('Jamie Bell', 46221189),
#  ('Ed Harris', 46221189),
#  ('Edward Burns', 46221189),
#  ('Isabel Lucas', 44806783),
#  ('Adrianne Palicki', 44806783),
#  ('Karl Urban', 41037742),
#  ('Olivia Thirlby', 41037742),
#  ('Lena Headey', 41037742),
#  ('Wood Harris', 41037742),
#  ('Jason Cope', 41037742),
#  ('Chris Sarandon', 40346186),
#  ('James Hong', 40346186),
#  ('Catherine Chan', 40346186),
#  ('Robert John Burke', 40346186),
#  ('Brad Pitt', 37930465),
#  ('Scoot McNairy', 37930465),
#  ('Ben Mendelsohn', 37930465),
#  ('James Gandolfini', 37930465),
#  ('Ray Liotta', 37930465),
#  ('Katherine Heigl', 36893721),
#  ('Debbie Reynolds', 36893721),
#  ('Sherri Shepherd', 36893721),
#  ('Patrick Fischler', 36893721),
#  ('Richard Gere', 35485056),
#  ('Tim Roth', 35485056),
#  ('Brit Marling', 35485056),
#  ('Monica Raymund', 35485056),
#  ('Logan Lerman', 33400000),
#  ('Emma Watson', 33400000),
#  ('Ezra Miller', 33400000),
#  ('Nina Dobrev', 33400000),
#  ('Gina Carano', 33372606),
#  ('Bill Paxton', 33372606),
#  ('John Krasinski', 32858003),
#  ('Katy Perry', 32726956),
#  ('Russell Brand', 32726956),
#  ('Shannon Woodward', 32726956),
#  ('Rachael Markarian', 32726956),
#  ('Mia Moretti', 32726956),
#  ('Joseph Gilgun', 32204030),
#  ('Lennie James', 32204030),
#  ('Peter Stormare', 32204030),
#  ('Michael Shannon', 31083599),
#  ('Dania Ramirez', 31083599),
#  ('Jamie Chung', 31083599),
#  ('WolÃ© Parks', 31083599),
#  ('Tyler Perry', 30353232),
#  ('Rachel Nichols', 30353232),
#  ('Jean Reno', 30353232),
#  ('Matthew Fox', 30353232),
#  ('Giancarlo Esposito', 30353232),
#  ('John Cusack', 29657751),
#  ('Luke Evans', 29657751),
#  ('Alice Eve', 29657751),
#  ('Kevin McNally', 29657751),
#  ('Joaquin Phoenix', 28258060),
#  ('Philip Seymour Hoffman', 28258060),
#  ('Amy Adams', 28258060),
#  ('Laura Dern', 28258060),
#  ('Jesse Plemons', 28258060),
#  ('Malin Ã…kerman', 26266491),
#  ('Olivia Wilde', 25666239),
#  ('Drew Barrymore', 24719215),
#  ('Kristen Bell', 24719215),
#  ('Vinessa Shaw', 24719215),
#  ('Dermot Mulroney', 24719215),
#  ('Whitney Houston', 24637469),
#  ('Cee Lo Green', 24637469),
#  ('Derek Luke', 24637469),
#  ('Mike Epps', 24637469),
#  ('Carmen Ejogo', 24637469),
#  ('Jennifer Aniston', 24159934),
#  ('Justin Theroux', 24159934),
#  ('Lauren Ambrose', 24159934),
#  ('Eddie Murphy', 22044277),
#  ('Allison Janney', 22044277),
#  ('Cliff Curtis', 22044277),
#  ('Clark Duke', 22044277),
#  ('Sam Rockwell', 19422261),
#  ('Christopher Walken', 19422261),
#  ('Abbie Cornish', 19422261),
#  ('Kirsten Dunst', 16890793),
#  ('Henry Cavill', 16863583),
#  ('VerÃ³nica Echegui', 16863583),
#  ('Sigourney Weaver', 16863583),
#  ('Caroline Goodall', 16863583),
#  ('Zoe Saldana', 13231461),
#  ('Jeremy Irons', 13231461),
#  ('Dennis Quaid', 13231461),
#  ('Mark Duplass', 12434778),
#  ('Victoria Justice', 11417362),
#  ('Jackson Nicoll', 11417362),
#  ('Chelsea Handler', 11417362),
#  ('Josh Pence', 11417362),
#  ('Jane Levy', 11417362),
#  ('Ashley Greene', 9627492),
#  ('Sebastian Stan', 9627492),
#  ('Tom Felton', 9627492),
#  ('Julianna Guill', 9627492),
#  ('Luke Pasqualino', 9627492),
#  ('Eva Longoria', 9622846),
#  ('Andy GarcÃ\xada', 9622846),
#  ('Oscar Isaac', 9622846),
#  ("Peter O'Toole", 9622846),
#  ('RubÃ©n Blades', 9622846),
#  ('Garrett Hedlund', 8784318),
#  ('Sam Riley', 8784318),
#  ('Tom Sturridge', 8784318),
#  ('Danielle Panabaker', 8493728),
#  ('Matt Bush', 8493728),
#  ('Katrina Bowden', 8493728),
#  ('Jean-Luc Bilodeau', 8493728),
#  ('David Koechner', 8493728),
#  ('Matt Damon', 8138788),
#  ('Rosemarie DeWitt', 8138788),
#  ('Lucas Black', 8138788),
#  ('Timothy Spall', 8106475),
#  ('James Kidnie', 8106475),
#  ('Heidi Hawkins', 8106475),
#  ('Sarah Gadon', 6063556),
#  ('Juliette Binoche', 6063556),
#  ('Paul Giamatti', 6063556),
#  ('Samantha Morton', 6063556),
#  ('Josh Duhamel', 4636169),
#  ('Rosario Dawson', 4636169),
#  ("Vincent D'Onofrio", 4636169),
#  ('50 Cent', 4636169),
#  ('Jason Bateman', 3428048),
#  ('Hope Davis', 3428048),
#  ('Frank Grillo', 3428048),
#  ('Paula Patton', 3428048),
#  ('Michael Nyqvist', 3428048),
#  ('Nicolas Cage', 2106557),
#  ('Josh Lucas', 2106557),
#  ('Sami Gayle', 2106557),
#  ('Danny Huston', 2106557)]

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
answers['16']='3. Matt Damon' #+

actor = Counter()
for x in data[(data['budget'] > data['budget'].mean())].cast.str.split('|'):
    actor += Counter(x)
actor.most_common(1)
# Out:
# [('Matt Damon', 18)]

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
answers['17']='2. Action' #+

Nick_Cage = Counter()
for x in data[data['cast'].str.contains('Nicolas Cage')].genres.str.split('|'):
    Nick_Cage += Counter(x)
Nick_Cage.most_common(1)
# Out:
# [('Action', 17)]

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
answers['18']='1. K-19: The Widowmaker (tt0267626)' #+

df_pp=data[data['production_companies'].str.contains('Paramount Pictures')] # для удобочитаемости решения
df_pp[(df_pp['profit'] == df_pp['profit'].min())]
# Out:
#        imdb_id     budget   revenue        original_title  \
# 925  tt0267626  100000000  35168966  K-19: The Widowmaker
#
#                                                   cast         director  \
# 925  Harrison Ford|Liam Neeson|Peter Sarsgaard|Joss...  Kathryn Bigelow
#
#                       tagline  \
# 925  Fate has found its hero.
#
#                                               overview  runtime  \
# 925  When Russia's first nuclear submarine malfunct...      138
#
#                      genres  \
# 925  Thriller|Drama|History
#
#                                   production_companies release_date  \
# 925  Paramount Pictures|Intermedia Films|National G...    7/19/2002
#
#      vote_average  release_year    profit  month  title_length  words_overview
# 925           6.0          2002 -64831034      7            20              23

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
answers['19']='5. 2015' #+

data.groupby(['release_year'])['revenue'].sum().sort_values(ascending=False)
# Out:
# release_year
# 2015    25449202382
# 2014    23405862953
# 2013    23213799791
# 2012    23079001687
# 2011    22676791872
# 2010    21071204961
# 2009    20261791024
# 2008    18252781990
# 2007    18162406801
# 2004    15663430720
# 2005    15309425558
# 2006    14775042320
# 2003    14346123312
# 2002    14136361487
# 2001    13017764865
# 2000    10664099805
# Name: revenue, dtype: int64

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
answers['20']='1. 2014' #+

df_wb=data[data['production_companies'].str.contains('Warner Bros')] # для удобочитаемости решения
df_wb.groupby(['release_year'])['profit'].sum().sort_values(ascending=False)
# Out:
# release_year
# 2014    2295464519
# 2007    2201675217
# 2008    2134595031
# 2010    1974712985
# 2011    1871393682
# 2003    1855493377
# 2009    1822454136
# 2013    1636453400
# 2004    1631933725
# 2005    1551980298
# 2001    1343545668
# 2012    1258020056
# 2002    1022709901
# 2015     870368348
# 2006     620170743
# 2000     452631386
# Name: profit, dtype: int64

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
answers['21']='4. Сентябрь' #+

data.groupby(['month']).nunique().sort_values(['imdb_id'],ascending=False)
# Out:
#        imdb_id  budget  revenue  original_title  cast  director  tagline  \
# month
# 9          227      70      227             227   227       192      227
# 12         190      80      190             190   187       145      189
# 10         186      67      186             186   186       163      186
# 8          161      65      161             161   161       147      161
# 3          156      74      156             156   156       137      156
# 4          149      66      149             149   149       137      148
# 6          147      68      147             147   147       127      147
# 11         146      65      146             146   145       134      146
# 7          142      66      142             142   142       122      142
# 5          140      77      140             140   137       127      140
# 2          135      54      135             135   135       121      135
# 1          110      45      110             110   110       105      110
#
#        overview  runtime  genres  production_companies  release_date  \
# month
# 9           227       65     132                   220           154
# 12          190       79     117                   185           135
# 10          186       62     112                   173           141
# 8           161       51     102                   152           124
# 3           156       54     118                   149           111
# 4           149       56     100                   138           115
# 6           147       57     102                   132           122
# 11          146       61     110                   139           114
# 7           142       62     105                   138           110
# 5           140       66     102                   133           116
# 2           135       49      95                   133           102
# 1           110       45      80                   108            91
#
#        vote_average  release_year  profit  title_length  words_overview
# month
# 9                33            16     227            36              82
# 12               36            16     190            41              74
# 10               37            16     186            31              71
# 8                32            16     161            34              82
# 3                30            16     156            31              77
# 4                30            16     149            29              71
# 6                38            16     147            38              73
# 11               31            16     146            36              80
# 7                33            16     142            32              68
# 5                31            16     140            34              69
# 2                31            16     135            30              73
# 1                33            16     110            25              65

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
answers['22']='2. 450' #+

len(data[(data['month'] >= 6) & (data['month'] <= 8)])
# Out:
# 450

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %%
answers['23']='5. Peter Jackson' #+

direct = Counter()
for x in data[((data['month'] >=1) & (data['month'] <=2)) | (data['month'] == 12)].director.str.split('|'):
    direct += Counter(x)
direct.most_common(1)
# Out:
# [('Peter Jackson', 7)]

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %%
answers['24']='5. Four By Two Productions' #+

lens={} #словарь для хранения данных по студии
for row in zip(data['production_companies'],data['title_length']): # отбираем нужные столбцы
    for studio in row[0].split('|'): 
        if(lens.setdefault(studio)  == None):
            lens[studio]=[row[1],1,row[1]]
        else:
            lens[studio][0] += row[1] #суммируем длины названий фильмов
            lens[studio][1] += 1 # сохраняем количество фильмов студии
            lens[studio][2] = lens[studio][0]/lens[studio][1] # сразу считаем среднюю длину
sorted(lens.items(), key=lambda item: item[1][2], reverse=True)
# Out:
# [('Four By Two Productions', [83, 1, 83]),
#  ('Jim Henson Company, The', [59, 1, 59]),
#  ('Dos Corazones', [47, 1, 47]),
#  ('Museum Canada Productions', [46, 1, 46]),
#  ('Polsky Films', [46, 1, 46]),
#  ('The Saul Zaentz Company', [86, 2, 43.0]),
#  ('Lucasfilm', [166, 4, 41.5]),
#  ('3Foot7', [41, 1, 41]),
#  ('Total Entertainment', [41, 1, 41]),
#  ('TSBD Canada Productions', [41, 1, 41]),
#  ('Zohar International', [41, 1, 41]),
#  ('Second Mate Productions', [82, 2, 41.0]),
#  ('Iron Film', [41, 1, 41]),
#  ('Cool Music', [41, 1, 41]),
#  ('Harry Potter Publishing Rights', [41, 1, 41]),
#  ('Nickelodeon Animation Studios', [40, 1, 40]),
#  ('United Plankton Pictures', [40, 1, 40]),
#  ('Ozumi Films', [40, 1, 40]),
#  ('Propeler', [40, 1, 40]),
#  ('P of A Productions Limited', [40, 1, 40]),
#  ('MIRACLE Productions GmbH & Co. KG', [39, 1, 39]),
#  ('Samuel Goldwyn Films', [78, 2, 39.0]),
#  ('The Javelina Film Company', [39, 1, 39]),
#  ('Chris Brinker Productions', [38, 1, 38]),
#  ('Alberta Film Entertainment', [76, 2, 38.0]),
#  ('Intandem Films', [37, 1, 37]),
#  ('Aramid Entertainment Fund', [37, 1, 37]),
#  ('Lipsync Productions', [37, 1, 37]),
#  ('JD Productions', [37, 1, 37]),
#  ('Unique Features', [37, 1, 37]),
#  ('Mr. Smith Productions', [37, 1, 37]),
#  ('Alloy Entertainment', [37, 1, 37]),
#  ('Natural Nylon Entertainment', [37, 1, 37]),
#  ('Riff Raff Film Productions', [37, 1, 37]),
#  ('Filmauro', [37, 1, 37]),
#  ('Blue Flower Productions', [37, 1, 37]),
#  ('What to Expect Productions', [36, 1, 36]),
#  ('Hammer & Tongs', [36, 1, 36]),
#  ('Capella International', [36, 1, 36]),
#  ('KC Medien AG', [36, 1, 36]),
#  ('Sony', [35, 1, 35]),
#  ('Patalex IV Productions Limited', [35, 1, 35]),
#  ('China Movie Channel', [34, 1, 34]),
#  ('Sparkler Entertainment', [34, 1, 34]),
#  ('Linsefilm', [34, 1, 34]),
#  ('Unity Productions', [34, 1, 34]),
#  ('Michael Cerenzie Productions', [34, 1, 34]),
#  ('Funky Buddha Productions', [34, 1, 34]),
#  ('Square USA', [33, 1, 33]),
#  ('The Collective Studios', [33, 1, 33]),
#  ('Atlantic Television', [33, 1, 33]),
#  ('British Broadcasting Corporation (BBC)', [65, 2, 32.5]),
#  ('Walt Disney', [160, 5, 32.0]),
#  ('Ikiru Films', [32, 1, 32]),
#  ('Heyday Films', [379, 12, 31.583333333333332]),
#  ('Bagdasarian Productions', [62, 2, 31.0]),
#  ('Banter', [31, 1, 31]),
#  ('Bungalow Productions', [31, 1, 31]),
#  ('Silver Lion Films', [31, 1, 31]),
#  ('Vision View Entertainment', [31, 1, 31]),
#  ('Yellow Bird', [31, 1, 31]),
#  ('Mr. Mudd Production', [31, 1, 31]),
#  ('Abraham Productions', [31, 1, 31]),
#  ('Location Gourmet', [31, 1, 31]),
#  ('Benderspink', [31, 1, 31]),
#  ('Carousel Productions', [31, 1, 31]),
#  ('Summertime Entertainment', [31, 1, 31]),
#  ('Kumar Mobiliengesellschaft mbH & Co. Projekt Nr. 2 KG', [62, 2, 31.0]),
#  ('UW3 Film Productions', [30, 1, 30]),
#  ('Edward R. Pressman Film', [150, 5, 30.0]),
#  ('Ten Thirteen Productions', [30, 1, 30]),
#  ('Crying Box Productions', [30, 1, 30]),
#  ('Magical Elves Productions', [30, 1, 30]),
#  ('Scooter Braun Films', [30, 1, 30]),
#  ('WingNut Films', [299, 10, 29.9]),
#  ('Earth Canada Productions', [29, 1, 29]),
#  ('HW Two', [29, 1, 29]),
#  ('Dickhouse Productions', [29, 1, 29]),
#  ('Distant Horizons', [29, 1, 29]),
#  ('Film Afrika Worldwide', [29, 1, 29]),
#  ('Videovision Entertainment', [29, 1, 29]),
#  ('Allied Filmmakers', [57, 2, 28.5]),
#  ('1492 Pictures', [367, 13, 28.23076923076923]),
#  ('Truenorth Productions', [28, 1, 28]),
#  ('Cloudy Productions', [28, 1, 28]),
#  ('Stanley Kubrick Productions', [28, 1, 28]),
#  ('Picturehouse Entertainment', [28, 1, 28]),
#  ('Havana Nights LLC', [28, 1, 28]),
#  ('Zanuck Company, The', [83, 3, 27.666666666666668]),
#  ('Animal Logic', [55, 2, 27.5]),
#  ('TC Productions', [82, 3, 27.333333333333332]),
#  ('21 Laps Entertainment', [243, 9, 27.0]),
#  ('Internationale Filmproduktion Blackswan', [27, 1, 27]),
#  ('Kontsept Film Company', [27, 1, 27]),
#  ('Necropia', [27, 1, 27]),
#  ('Tequila Gang', [27, 1, 27]),
#  ("Eric's Boy", [27, 1, 27]),
#  ('Moving Pictures', [27, 1, 27]),
#  ('Gratitude International', [27, 1, 27]),
#  ('Madacy Entertainment', [54, 2, 27.0]),
#  ('Mostow/Lieberman Productions', [27, 1, 27]),
#  ('80 Days Productions', [27, 1, 27]),
#  ('I Could Never Ltd.', [27, 1, 27]),
#  ('Bauer Martinez Studios', [27, 1, 27]),
#  ('Type A Films', [53, 2, 26.5]),
#  ('Capitol Films', [53, 2, 26.5]),
#  ('Prana Animation Studios', [52, 2, 26.0]),
#  ('Smoke House', [26, 1, 26]),
#  ('The Tyler Perry Company', [26, 1, 26]),
#  ('Blue Askew', [26, 1, 26]),
#  ('Nouvelles Ã‰ditions de Films (NEF)', [52, 2, 26.0]),
#  ('Room 101', [78, 3, 26.0]),
#  ('Solana Films', [78, 3, 26.0]),
#  ('Konami Corporation Ltd.', [26, 1, 26]),
#  ('Verisimilitude', [26, 1, 26]),
#  ('Sketch Films', [51, 2, 25.5]),
#  ('DreamWorks Pictures', [178, 7, 25.428571428571427]),
#  ('Junction Entertainment', [76, 3, 25.333333333333332]),
#  ('Sunswept Entertainment', [250, 10, 25.0]),
#  ('Mad Hatter Entertainment', [50, 2, 25.0]),
#  ('Etalon film', [25, 1, 25]),
#  ("It's a Laugh Productions", [25, 1, 25]),
#  ('Millar Gough Ink', [25, 1, 25]),
#  ('Universal Cartoon Studios', [25, 1, 25]),
#  ('Marvel Knights', [50, 2, 25.0]),
#  ('C-2 Pictures', [50, 2, 25.0]),
#  ('Big Beach Productions', [25, 1, 25]),
#  ('Telegraph Films', [25, 1, 25]),
#  ('Cowboy Films', [25, 1, 25]),
#  ('Constantin Film Ltd.', [25, 1, 25]),
#  ('Primal Foe Productions', [25, 1, 25]),
#  ('Resident Evil Productions', [25, 1, 25]),
#  ('Color Force', [197, 8, 24.625]),
#  ('Angry Films', [49, 2, 24.5]),
#  ('Mediastream Dritte Film GmbH & Co. Beteiligungs KG', [49, 2, 24.5]),
#  ('Splendid Pictures', [73, 3, 24.333333333333332]),
#  ('Wigram Productions', [72, 3, 24.0]),
#  ('Avi Arad Productions', [24, 1, 24]),
#  ('Matt Tolmach Productions', [24, 1, 24]),
#  ('Long Distance Films', [24, 1, 24]),
#  ('Mediastream Film GmbH & Co. Productions KG', [24, 1, 24]),
#  ('China Film Co-Production Corporation', [96, 4, 24.0]),
#  ('Sommers Company, The', [48, 2, 24.0]),
#  ('Gravier Productions', [24, 1, 24]),
#  ('Antena 3 Films', [24, 1, 24]),
#  ('TelevisiÃ³ de Catalunya (TV3)', [24, 1, 24]),
#  ('Antena 3 TelevisiÃ³n', [24, 1, 24]),
#  ('MPH Entertainment', [24, 1, 24]),
#  ('Aardman Animations', [96, 4, 24.0]),
#  ('Stoller Global Solutions', [24, 1, 24]),
#  ('Dylan Sellers Productions', [72, 3, 24.0]),
#  ('Rainmaker Entertainment', [24, 1, 24]),
#  ('Mainframe Entertainment', [24, 1, 24]),
#  ('Really Useful Films', [24, 1, 24]),
#  ('Walden Media', [382, 16, 23.875]),
#  ('Red Hour Films', [95, 4, 23.75]),
#  ('Jerry Bruckheimer Films', [448, 19, 23.57894736842105]),
#  ('Revolution Sun Studios', [94, 4, 23.5]),
#  ('Miramax', [93, 4, 23.25]),
#  ('Temple Hill Entertainment', [185, 8, 23.125]),
#  ('K. JAM Media', [23, 1, 23]),
#  ('Bulletproof Cupid', [23, 1, 23]),
#  ('Maverick Films', [115, 5, 23.0]),
#  ('Midnight Picture Show', [23, 1, 23]),
#  ('Film Rites', [69, 3, 23.0]),
#  ('Parkes+MacDonald Image Nation', [69, 3, 23.0]),
#  ('EMJAG Productions', [23, 1, 23]),
#  ('Milkshake Films', [23, 1, 23]),
#  ('Hargitay & Hargitay Pictures in Motion', [23, 1, 23]),
#  ('MI 3 Film', [23, 1, 23]),
#  ('Rocket Pictures', [23, 1, 23]),
#  ('Alliance Atlantis Motion Picture Production', [23, 1, 23]),
#  ('Bird and a Bear Entertainment', [23, 1, 23]),
#  ('Hallway Pictures', [23, 1, 23]),
#  ('Catch Productions', [23, 1, 23]),
#  ('International Production Company', [68, 3, 22.666666666666668]),
#  ('Artisan Entertainment', [68, 3, 22.666666666666668]),
#  ('Insurge Pictures', [67, 3, 22.333333333333332]),
#  ('Depth of Field', [67, 3, 22.333333333333332]),
#  ('Toho-Towa', [89, 4, 22.25]),
#  ('Broken Chair Flickz', [22, 1, 22]),
#  ('Volcano Films', [22, 1, 22]),
#  ('Mosaic', [22, 1, 22]),
#  ('Neal H. Moritz Productions', [22, 1, 22]),
#  ('South Pacific Pictures', [22, 1, 22]),
#  ('Spice Factory', [22, 1, 22]),
#  ('The Australian Film Commission', [22, 1, 22]),
#  ('Universal Pictures Corporation', [22, 1, 22]),
#  ('ARP SÃ©lection', [22, 1, 22]),
#  ('Indigo Film', [22, 1, 22]),
#  ('Medusa Film', [22, 1, 22]),
#  ('Mutant Enemy Productions', [22, 1, 22]),
#  ('Warner Independent Pictures (WIP)', [88, 4, 22.0]),
#  ('JC 23 Entertainment', [22, 1, 22]),
#  ('Liaison Films', [22, 1, 22]),
#  ('Cent Productions Inc.', [22, 1, 22]),
#  ('Mark Gordon Productions', [22, 1, 22]),
#  ('Munich Film Partners & Company (MFP) MI2 Productions', [22, 1, 22]),
#  ('View Askew Productions', [65, 3, 21.666666666666668]),
#  ('Everyman Pictures', [85, 4, 21.25]),
#  ('Cruel and Unusual Films', [85, 4, 21.25]),
#  ('Moving Picture Company (MPC)', [231, 11, 21.0]),
#  ('Origin Pictures', [42, 2, 21.0]),
#  ('Hasbro Studios', [21, 1, 21]),
#  ('Allspark Pictures', [21, 1, 21]),
#  ('Huayi Brothers', [21, 1, 21]),
#  ('New Wave Entertainment', [21, 1, 21]),
#  ('Terra Firma Films', [21, 1, 21]),
#  ('Superfinger Entertainment', [21, 1, 21]),
#  ('Gambit Pictures', [21, 1, 21]),
#  ('Electric Shepherd Productions', [21, 1, 21]),
#  ('Atlas Productions', [21, 1, 21]),
#  ('UW4 Productions', [21, 1, 21]),
#  ('Galavis Film', [21, 1, 21]),
#  ('Picture Machine', [21, 1, 21]),
#  ('Room 9 Entertainment', [21, 1, 21]),
#  ('Aldrich Group', [21, 1, 21]),
#  ('Optional Pictures', [21, 1, 21]),
#  ('NALA Films', [21, 1, 21]),
#  ('Samuels Media', [21, 1, 21]),
#  ('Hyde Park Films', [104, 5, 20.8]),
#  ('Nickelodeon Movies', [290, 14, 20.714285714285715]),
#  ('Goldmann Pictures', [62, 3, 20.666666666666668]),
#  ('Three Strange Angels', [62, 3, 20.666666666666668]),
#  ('Hasbro', [103, 5, 20.6]),
#  ('AR Films', [41, 2, 20.5]),
#  ('Demarest Films', [41, 2, 20.5]),
#  ('Chris Lee Productions', [41, 2, 20.5]),
#  ('Indochina Productions', [41, 2, 20.5]),
#  ('Pathe', [41, 2, 20.5]),
#  ('Imprint Entertainment', [61, 3, 20.333333333333332]),
#  ('Walt Disney Studios Motion Pictures', [60, 3, 20.0]),
#  ('Sony Pictures Releasing', [60, 3, 20.0]),
#  ('Why Not Productions', [40, 2, 20.0]),
#  ('Zehnte Babelsberg', [20, 1, 20]),
#  ('Visiona Romantica', [20, 1, 20]),
#  ('The Halcyon Company', [20, 1, 20]),
#  ('Watermark', [20, 1, 20]),
#  ('Practical Pictures', [40, 2, 20.0]),
#  ('Parallel Zide', [40, 2, 20.0]),
#  ('Medienproduktion Prometheus Filmgesellschaft', [20, 1, 20]),
#  ('Portobello Studios', [20, 1, 20]),
#  ('New Crime Productions', [20, 1, 20]),
#  ('Omnilab Media', [40, 2, 20.0]),
#  ('Ambience Entertainment', [40, 2, 20.0]),
#  ('platinum studios', [40, 2, 20.0]),
#  ('BrownHouse Productions', [20, 1, 20]),
#  ('Bottom of the Ninth Productions', [20, 1, 20]),
#  ('Merlin Films', [20, 1, 20]),
#  ('Ardustry Entertainment', [40, 2, 20.0]),
#  ('VIP Medienfonds 4', [60, 3, 20.0]),
#  ('Mpower Pictures', [20, 1, 20]),
#  ('Lip Sync Post', [20, 1, 20]),
#  ('Trademark Films', [20, 1, 20]),
#  ('Runteldat Entertainment', [40, 2, 20.0]),
#  ('National Geographic Society', [20, 1, 20]),
#  ('Walt Disney Animation Canada', [20, 1, 20]),
#  ('Tall Trees Productions', [40, 2, 20.0]),
#  ('Jean Doumanian Productions', [20, 1, 20]),
#  ('Art Pictures Studio', [20, 1, 20]),
#  ('Landscape Entertainment', [20, 1, 20]),
#  ('John US Productions', [20, 1, 20]),
#  ('Big Beach Films', [20, 1, 20]),
#  ('Motion Picture THETA Produktionsgesellschaft', [20, 1, 20]),
#  ('Ludlum Entertainment', [40, 2, 20.0]),
#  ('Mediastream Vierte Film GmbH & Co. Vermarktungs KG', [40, 2, 20.0]),
#  ('Motion Picture BETA Produktionsgesellschaft', [20, 1, 20]),
#  ('Bourne Again', [20, 1, 20]),
#  ('Lauren Levine Productions Inc.', [20, 1, 20]),
#  ('360 Pictures', [20, 1, 20]),
#  ('Land Films Inc.', [20, 1, 20]),
#  ('Tyler Perry Company, The', [20, 1, 20]),
#  ('Nine Yards Productions', [20, 1, 20]),
#  ('Rational Packaging Company', [20, 1, 20]),
#  ('Platinum Dunes', [238, 12, 19.833333333333332]),
#  ('TSG Entertainment', [297, 15, 19.8]),
#  ('Flower Films (II)', [99, 5, 19.8]),
#  ('Route One Films', [39, 2, 19.5]),
#  ('Scottish Screen', [39, 2, 19.5]),
#  ('HBO Films', [39, 2, 19.5]),
#  ('Little Bird', [39, 2, 19.5]),
#  ('Skydance Productions', [175, 9, 19.444444444444443]),
#  ('DisneyToon Studios', [58, 3, 19.333333333333332]),
#  ('This Is That Productions', [58, 3, 19.333333333333332]),
#  ('Davis-Films', [192, 10, 19.2]),
#  ('Mutual Film Company', [96, 5, 19.2]),
#  ('Sony Pictures Animation', [171, 9, 19.0]),
#  ('TriStar Productions', [19, 1, 19]),
#  ('Disney', [19, 1, 19]),
#  ('Max Films Productions', [19, 1, 19]),
#  ('Morag Loves Company', [19, 1, 19]),
#  ('Grand Army Entertainment', [19, 1, 19]),
#  ('Hachiko', [19, 1, 19]),
#  ('Film Department, The', [19, 1, 19]),
#  ('Evil Twins', [19, 1, 19]),
#  ('Warp Films', [19, 1, 19]),
#  ('New Upstairs Productions', [19, 1, 19]),
#  ('Upstairs Canada Productions', [19, 1, 19]),
#  ('Freestyle Releasing', [19, 1, 19]),
#  ('FidÃ©litÃ© Films', [19, 1, 19]),
#  ('Hwy61', [19, 1, 19]),
#  ('AZL Productions KG', [19, 1, 19]),
#  ('MFP Munich Film Partners', [19, 1, 19]),
#  ('Phase 1 Productions', [19, 1, 19]),
#  ('Dee Gee Entertainment', [19, 1, 19]),
#  ('Prufrock Pictures', [19, 1, 19]),
#  ('Cort/Madden Productions', [19, 1, 19]),
#  ('MVL Incredible Productions', [19, 1, 19]),
#  ('Hammerhead Productions', [38, 2, 19.0]),
#  ('Flashpoint Entertainment', [19, 1, 19]),
#  ('Kemp Company', [19, 1, 19]),
#  ('WV Films LLC', [19, 1, 19]),
#  ('Cott Productions', [19, 1, 19]),
#  ('Furia de Titanes II, A.I.E.', [19, 1, 19]),
#  ('Inferno Entertainment', [19, 1, 19]),
#  ('Heineken Branded Entertainment', [19, 1, 19]),
#  ('Doom Buggy Productions', [19, 1, 19]),
#  ('Alphaville Productions', [19, 1, 19]),
#  ('Earthship Productions', [19, 1, 19]),
#  ('Paco Cinematografica', [19, 1, 19]),
#  ('Regione Lazio', [19, 1, 19]),
#  ('Business Location Sudtirol Alto Adige', [19, 1, 19]),
#  ('Friuli Venezia Giulia Film Commission', [19, 1, 19]),
#  ('Matinee Pictures', [19, 1, 19]),
#  ('Starbucks Entertainment', [19, 1, 19]),
#  ('Cinema Gypsy Productions', [19, 1, 19]),
#  ('Eclipse Catering', [19, 1, 19]),
#  ('Nine Yards Two Productions', [19, 1, 19]),
#  ('Friday Night Lights LLC', [19, 1, 19]),
#  ('MDBF Filmgesellschaft mbH & Company KG', [19, 1, 19]),
#  ('Block 2 Pictures', [19, 1, 19]),
#  ('Jet Tone Production', [19, 1, 19]),
#  ('Lou Yi Inc.', [19, 1, 19]),
#  ('Technical Black', [19, 1, 19]),
#  ('Run It Up Productions Inc.', [19, 1, 19]),
#  ('Seven Arts Pictures', [19, 1, 19]),
#  ('Munich Film Partners & Company (MFP) ROE Production', [19, 1, 19]),
#  ('Davis-Panzer Productions', [19, 1, 19]),
#  ('Bad Robot', [169, 9, 18.77777777777778]),
#  ('Wildwood Enterprises', [75, 4, 18.75]),
#  ('The Kennedy/Marshall Company', [75, 4, 18.75]),
#  ('Roth Films', [131, 7, 18.714285714285715]),
#  ('Studio Babelsberg', [374, 20, 18.7]),
#  ('Plan B Entertainment', [187, 10, 18.7]),
#  ('Lawrence Gordon Productions', [112, 6, 18.666666666666668]),
#  ('DiNovi Pictures', [56, 3, 18.666666666666668]),
#  ('Apatow Productions', [354, 19, 18.63157894736842]),
#  ('Saturn Films', [242, 13, 18.615384615384617]),
#  ('Stage 6 Films', [93, 5, 18.6]),
#  ('Constantin Film Produktion', [186, 10, 18.6]),
#  ('Fox 2000 Pictures', [649, 35, 18.542857142857144]),
#  ('Marvel Entertainment', [111, 6, 18.5]),
#  ('Sikelia Productions', [37, 2, 18.5]),
#  ('Stillking Films', [148, 8, 18.5]),
#  ('MHF Zweite Academy Film', [37, 2, 18.5]),
#  ('Walt Disney Television Animation', [37, 2, 18.5]),
#  ('Walt Disney Animation Australia', [37, 2, 18.5]),
#  ('Studio Canal', [203, 11, 18.454545454545453]),
#  ('IMF Internationale Medien und Film GmbH & Co. 3. Produktions KG',
#   [55, 3, 18.333333333333332]),
#  ('Baltimore Spring Creek Productions', [55, 3, 18.333333333333332]),
#  ('Scott Rudin Productions', [439, 24, 18.291666666666668]),
#  ('Tim Burton Productions', [201, 11, 18.272727272727273]),
#  ('Indian Paintbrush', [91, 5, 18.2]),
#  ('Lin Pictures', [91, 5, 18.2]),
#  ('River Road Entertainment', [109, 6, 18.166666666666668]),
#  ('Gotham Group', [54, 3, 18.0]),
#  ('Sierra/Affinity', [18, 1, 18]),
#  ('Sony Pictures Home Entertainment', [36, 2, 18.0]),
#  ('Ingenious Media', [198, 11, 18.0]),
#  ('Clinica Estetico', [54, 3, 18.0]),
#  ('Black Bear Pictures', [18, 1, 18]),
#  ('Bristol Automotive', [18, 1, 18]),
#  ('5150 Action', [18, 1, 18]),
#  ('The Combine', [18, 1, 18]),
#  ('A Band Apart', [54, 3, 18.0]),
#  ('Mark Johnson Productions', [18, 1, 18]),
#  ('Curmudgeon Films', [18, 1, 18]),
#  ('Industrial Light & Magic (ILM)', [18, 1, 18]),
#  ('Village Roadshow Pictures Asia', [18, 1, 18]),
#  ('Parabolic Pictures', [18, 1, 18]),
#  ('Birdsong Pictures', [18, 1, 18]),
#  ('Swanford Films', [18, 1, 18]),
#  ('KC Medien', [18, 1, 18]),
#  ('Immortal Entertainment', [18, 1, 18]),
#  ('SGF Entertainment', [18, 1, 18]),
#  ('Evamere Entertainment', [18, 1, 18]),
#  ('Odyssey Entertainment', [36, 2, 18.0]),
#  ('Playtone Productions', [36, 2, 18.0]),
#  ('Wild Ocean Films', [18, 1, 18]),
#  ('2S Films', [18, 1, 18]),
#  ('Recorded Pictures Company', [18, 1, 18]),
#  ('The Movie Network', [18, 1, 18]),
#  ('Millbrook Pictures', [18, 1, 18]),
#  ('Lago Film', [18, 1, 18]),
#  ('Corrino Media Corporation', [18, 1, 18]),
#  ('Corsan', [18, 1, 18]),
#  ('Staccato Films', [18, 1, 18]),
#  ('Pandora Pictures', [18, 1, 18]),
#  ('Talisman Productions', [18, 1, 18]),
#  ('Myriad Pictures', [18, 1, 18]),
#  ('Jeepers Creepers II', [18, 1, 18]),
#  ('Truth Entertainment', [18, 1, 18]),
#  ('Reforma Films', [18, 1, 18]),
#  ('Persistent Entertainment', [18, 1, 18]),
#  ('Section Eight Productions', [72, 4, 18.0]),
#  ('Dante Entertainment', [18, 1, 18]),
#  ('Crusader Entertainment', [18, 1, 18]),
#  ('O.N.C. Entertainment', [18, 1, 18]),
#  ('Hard Eight Pictures', [36, 2, 18.0]),
#  ('VIP 4 Medienfonds', [18, 1, 18]),
#  ('MMCB Film Produktion 2004', [18, 1, 18]),
#  ('Daybreak', [18, 1, 18]),
#  ('Gaylord Films', [18, 1, 18]),
#  ('Scholastic Productions', [18, 1, 18]),
#  ('Marshall Production', [18, 1, 18]),
#  ('Fine Line Features', [18, 1, 18]),
#  ('Zentropa Entertainments', [18, 1, 18]),
#  ('Danmarks Radio (DR)', [18, 1, 18]),
#  ('SVT Drama', [18, 1, 18]),
#  ('Arte', [18, 1, 18]),
#  ('Sweetpea Entertainment', [18, 1, 18]),
#  ('Amblin Entertainment', [411, 23, 17.869565217391305]),
#  ('Castle Rock Entertainment', [268, 15, 17.866666666666667]),
#  ('Red Granite Pictures', [71, 4, 17.75]),
#  ('Blumhouse Productions', [195, 11, 17.727272727272727]),
#  ('Team Todd', [53, 3, 17.666666666666668]),
#  ('Hyde Park Entertainment', [53, 3, 17.666666666666668]),
#  ('Spring Creek Productions', [105, 6, 17.5]),
#  ('Kurtzman/Orci', [35, 2, 17.5]),
#  ('Grosvenor Park Media Ltd.', [70, 4, 17.5]),
#  ('New Line Cinema', [1531, 88, 17.397727272727273]),
#  ('Disruption Entertainment', [52, 3, 17.333333333333332]),
#  ('Tribeca Productions', [104, 6, 17.333333333333332]),
#  ('FilmEngine', [52, 3, 17.333333333333332]),
#  ('Lonely Film Productions GmbH & Co. KG.', [52, 3, 17.333333333333332]),
#  ('Impact Pictures', [155, 9, 17.22222222222222]),
#  ('MTV Films', [206, 12, 17.166666666666668]),
#  ('Big Screen Productions', [103, 6, 17.166666666666668]),
#  ('Dune Entertainment', [755, 44, 17.15909090909091]),
#  ('Marvel Studios', [205, 12, 17.083333333333332]),
#  ('Walt Disney Pictures', [1398, 82, 17.048780487804876]),
#  ('Paramount Pictures', [2078, 122, 17.0327868852459]),
#  ('FilmColony', [34, 2, 17.0]),
#  ('Babieka', [34, 2, 17.0]),
#  ('Orange Studios', [17, 1, 17]),
#  ('CityMation', [17, 1, 17]),
#  ('On Entertainment', [17, 1, 17]),
#  ('Zippcast Films', [17, 1, 17]),
#  ('Lynda Obst Productions', [34, 2, 17.0]),
#  ('Ex3 Productions', [17, 1, 17]),
#  ('1984 Private Defense Contractors', [85, 5, 17.0]),
#  ('Obelisk Productions', [17, 1, 17]),
#  ('Electric City Entertainment', [34, 2, 17.0]),
#  ('Seven West Media', [17, 1, 17]),
#  ('Fear of God Films', [17, 1, 17]),
#  ('Seven Group Holdings', [17, 1, 17]),
#  ('Affirm Films', [51, 3, 17.0]),
#  ('Langley Productions', [17, 1, 17]),
#  ('Thunder Road Productions', [17, 1, 17]),
#  ('Fuqua Films', [17, 1, 17]),
#  ('Tooley Productions', [17, 1, 17]),
#  ('Tapestry Films', [85, 5, 17.0]),
#  ('Great Scott Productions Pty. Ltd.', [17, 1, 17]),
#  ('Bedlam Productions', [17, 1, 17]),
#  ('See-Saw Films', [17, 1, 17]),
#  ('Home Box Office (HBO)', [34, 2, 17.0]),
#  ('Spy Next Door', [17, 1, 17]),
#  ('Imhotep Productions', [17, 1, 17]),
#  ('Initial Entertainment Group', [17, 1, 17]),
#  ('Blue Star Pictures', [34, 2, 17.0]),
#  ('First Foot Films', [17, 1, 17]),
#  ('Crystal City Entertainment', [17, 1, 17]),
#  ('Prospero Pictures', [51, 3, 17.0]),
#  ('Sony Pictures Worldwide Acquisitions (SPWA)', [17, 1, 17]),
#  ('TDJ Enterprises / New Dimensions Entertainment', [17, 1, 17]),
#  ('Our Stories Films', [17, 1, 17]),
#  ('Hughes Entertainment', [17, 1, 17]),
#  ('Shoelace Productions', [17, 1, 17]),
#  ('Alberto Grimaldi Productions', [17, 1, 17]),
#  ('Hacienda Productions', [17, 1, 17]),
#  ('World Wrestling Entertainment (WWE)', [17, 1, 17]),
#  ('Schroeder Hoffman Productions', [17, 1, 17]),
#  ('Jaffilms Inc.', [17, 1, 17]),
#  ('Captivate Entertainment', [17, 1, 17]),
#  ('Super Cool ManChu', [34, 2, 17.0]),
#  ('Turner Pictures', [17, 1, 17]),
#  ('Antietam Filmworks', [17, 1, 17]),
#  ('Boll Kino Beteiligungs GmbH & Co. KG', [34, 2, 17.0]),
#  ('Herold Productions', [34, 2, 17.0]),
#  ('Mindfire Entertainment', [17, 1, 17]),
#  ('K5 International', [17, 1, 17]),
#  ('Infogrames Entertainment', [17, 1, 17]),
#  ('Government of Malta', [17, 1, 17]),
#  ('Failure to Launch Productions', [17, 1, 17]),
#  ('Golden Mean', [17, 1, 17]),
#  ('Universal CGI', [17, 1, 17]),
#  ('Film Colony', [17, 1, 17]),
#  ('Fountainbridge Films', [17, 1, 17]),
#  ('Finding Forrester Productions', [17, 1, 17]),
#  ('Triple Threat Talent', [17, 1, 17]),
#  ('Wonderland Sound and Vision', [84, 5, 16.8]),
#  ('Gran Via Productions', [84, 5, 16.8]),
#  ('Radar Pictures', [151, 9, 16.77777777777778]),
#  ('UK Film Council', [285, 17, 16.764705882352942]),
#  ('Paradox Entertainment', [67, 4, 16.75]),
#  ('Virtual Studios', [117, 7, 16.714285714285715]),
#  ('BBC Films', [267, 16, 16.6875]),
#  ('Next Entertainment', [50, 3, 16.666666666666668]),
#  ('Walt Disney Feature Animation', [116, 7, 16.571428571428573]),
#  ('Alcon Entertainment', [248, 15, 16.533333333333335]),
#  ('Twentieth Century Fox Film Corporation', [1799, 109, 16.504587155963304]),
#  ('Prana Studios', [33, 2, 16.5]),
#  ('Hopscotch Features', [33, 2, 16.5]),
#  ('American Empirical Pictures', [33, 2, 16.5]),
#  ('Seed Productions', [33, 2, 16.5]),
#  ('Neal Street Productions', [66, 4, 16.5]),
#  ('2 Entertain', [33, 2, 16.5]),
#  ('Management 360', [33, 2, 16.5]),
#  ('New Legacy', [33, 2, 16.5]),
#  ('Material', [33, 2, 16.5]),
#  ('Kumar Mobiliengesellschaft mbH & Co. Projekt Nr. 1 KG', [33, 2, 16.5]),
#  ('Playtone Production', [33, 2, 16.5]),
#  ('Kernos Filmproduktionsgesellschaft & Company', [33, 2, 16.5]),
#  ('Nu Image Films', [181, 11, 16.454545454545453]),
#  ('Gary Sanchez Productions', [115, 7, 16.428571428571427]),
#  ('Sidney Kimmel Entertainment', [131, 8, 16.375]),
#  ('Buena Vista', [49, 3, 16.333333333333332]),
#  ('Cube Vision', [49, 3, 16.333333333333332]),
#  ('Mandate Pictures', [147, 9, 16.333333333333332]),
#  ('WV Films III', [49, 3, 16.333333333333332]),
#  ('Mike Zoss Productions', [81, 5, 16.2]),
#  ('The Zanuck Company', [97, 6, 16.166666666666668]),
#  ('Alphaville Films', [97, 6, 16.166666666666668]),
#  ('DreamWorks Animation', [420, 26, 16.153846153846153]),
#  ('Imagenation Abu Dhabi FZ', [193, 12, 16.083333333333332]),
#  ('Prime Focus', [32, 2, 16.0]),
#  ('Infinite Frameworks Studios', [16, 1, 16]),
#  ('Columbia TriStar', [32, 2, 16.0]),
#  ('Viz Media', [16, 1, 16]),
#  ('Irish Dreamtime', [16, 1, 16]),
#  ('SPD Films', [16, 1, 16]),
#  ('Qwerty Films', [16, 1, 16]),
#  ('TF1 Droits Audiovisuels', [16, 1, 16]),
#  ('Ingenious Film Partners', [304, 19, 16.0]),
#  ('Dune Entertainment III', [272, 17, 16.0]),
#  ('Skylark Productions', [32, 2, 16.0]),
#  ('Fortis Films', [48, 3, 16.0]),
#  ('Gunn Films', [64, 4, 16.0]),
#  ('Rogue', [32, 2, 16.0]),
#  ('Sid & Marty Krofft Pictures', [16, 1, 16]),
#  ('26 Films', [32, 2, 16.0]),
#  ('Runteam Ltd.', [16, 1, 16]),
#  ('R.P. Productions', [16, 1, 16]),
#  ('Henceforth', [16, 1, 16]),
#  ('Projection Pictures', [16, 1, 16]),
#  ('London Boulevard', [16, 1, 16]),
#  ('Penn Station Entertainment', [32, 2, 16.0]),
#  ('Serendipity Point Films', [32, 2, 16.0]),
#  ('HighRoad Entertainment', [16, 1, 16]),
#  ('Prelude Pictures', [16, 1, 16]),
#  ('Lone Runner Entertainment', [16, 1, 16]),
#  ('Kenio Films', [16, 1, 16]),
#  ('Perfect Game, The', [16, 1, 16]),
#  ('Asymmetrical Productions', [16, 1, 16]),
#  ('Les Films Alain Sarde', [16, 1, 16]),
#  ('Babbo Inc.', [16, 1, 16]),
#  ('The Picture Factory', [16, 1, 16]),
#  ('Zide-Perry Productions', [96, 6, 16.0]),
#  ('Lucky Red', [32, 2, 16.0]),
#  ('Cinerenta-Cinebeta', [16, 1, 16]),
#  ('VCL Communications', [16, 1, 16]),
#  ('Ott Medien', [16, 1, 16]),
#  ('Darren Star Productions', [16, 1, 16]),
#  ('Bay Films', [16, 1, 16]),
#  ('British Film Council', [16, 1, 16]),
#  ('Icon Entertainment International', [64, 4, 16.0]),
#  ('Wheelhouse Entertainment', [16, 1, 16]),
#  ('Motion Picture Production GmbH & Co. Erste KG', [16, 1, 16]),
#  ('Moonrise', [16, 1, 16]),
#  ('First Light Production', [16, 1, 16]),
#  ('Varsity Pictures', [16, 1, 16]),
#  ('Studio Mir', [16, 1, 16]),
#  ('Loumolo & Co.', [16, 1, 16]),
#  ('Jackie Chan Films Limited', [16, 1, 16]),
#  ('All Knight Productions', [16, 1, 16]),
#  ('Michael Lobell Productions', [16, 1, 16]),
#  ('Cecchi Gori Group Tiger Cinematografica', [16, 1, 16]),
#  ('A&E Television Networks', [16, 1, 16]),
#  ('Mythology Entertainment (II)', [16, 1, 16]),
#  ('Essential Media & Entertainment', [16, 1, 16]),
#  ('Dutch Oven', [16, 1, 16]),
#  ('New Regency Productions', [16, 1, 16]),
#  ('The Ladd Company', [32, 2, 16.0]),
#  ('ShadowCatcher Entertainment', [16, 1, 16]),
#  ('Daniel Bobker Productions', [16, 1, 16]),
#  ('Biscayne Pictures', [32, 2, 16.0]),
#  ('Romero-Grunwald Productions', [16, 1, 16]),
#  ('Exception Wild Bunch', [16, 1, 16]),
#  ('Callahan Filmworks', [16, 1, 16]),
#  ('Pricel', [16, 1, 16]),
#  ('Tohokushinsha Film', [16, 1, 16]),
#  ('Commission du Film France', [16, 1, 16]),
#  ('Thousand Words', [16, 1, 16]),
#  ('Detour Filmproduction', [16, 1, 16]),
#  ('Paramount Classics', [16, 1, 16]),
#  ('Loofah Productions', [16, 1, 16]),
#  ('New Amsterdam Entertainment', [16, 1, 16]),
#  ('HorrorFlix', [16, 1, 16]),
#  ('Astral Media', [16, 1, 16]),
#  ('Reserve Room', [16, 1, 16]),
#  ('Dino de Laurentiis Cinematografica', [16, 1, 16]),
#  ('Red Lion Sarl', [16, 1, 16]),
#  ('Nancy Tenenbaum Films', [16, 1, 16]),
#  ('Imagine Entertainment', [394, 25, 15.76]),
#  ('Harpo Films', [47, 3, 15.666666666666666]),
#  ('Rising Star', [94, 6, 15.666666666666666]),
#  ('Di Bonaventura Pictures', [219, 14, 15.642857142857142]),
#  ('American Zoetrope', [78, 5, 15.6]),
#  ('Warner Bros.', [2616, 168, 15.571428571428571]),
#  ('Scion Films', [171, 11, 15.545454545454545]),
#  ('Energy Entertainment', [31, 2, 15.5]),
#  ('LionsGate', [31, 2, 15.5]),
#  ('The Jacobson Company', [31, 2, 15.5]),
#  ('MacDonald/Parkes Productions', [31, 2, 15.5]),
#  ('Babelsberg Film', [31, 2, 15.5]),
#  ('Smokehouse Pictures', [77, 5, 15.4]),
#  ('Warner Bros. Animation', [77, 5, 15.4]),
#  ('Dark Horse Entertainment', [77, 5, 15.4]),
#  ('Kennedy/Marshall Company, The', [123, 8, 15.375]),
#  ('Katalyst Films', [46, 3, 15.333333333333334]),
#  ('Weinstein Company, The', [46, 3, 15.333333333333334]),
#  ('Zephyr Films', [46, 3, 15.333333333333334]),
#  ('Cruise/Wagner Productions', [153, 10, 15.3]),
#  ('Appian Way', [137, 9, 15.222222222222221]),
#  ('Lakeshore Entertainment', [365, 24, 15.208333333333334]),
#  ('Fox Searchlight Pictures', [365, 24, 15.208333333333334]),
#  ('Mid Atlantic Films', [76, 5, 15.2]),
#  ('Bazelevs Production', [76, 5, 15.2]),
#  ('Paramount Animation', [76, 5, 15.2]),
#  ('Millennium Films', [257, 17, 15.117647058823529]),
#  ('Miramax Films', [589, 39, 15.102564102564102]),
#  ('Village Roadshow Pictures', [949, 63, 15.063492063492063]),
#  ('Metro-Goldwyn-Mayer (MGM)', [723, 48, 15.0625]),
#  ('20th Century Fox', [256, 17, 15.058823529411764]),
#  ('Working Title Films', [406, 27, 15.037037037037036]),
#  ('One Race Films', [30, 2, 15.0]),
#  ('Gold Circle Films', [90, 6, 15.0]),
#  ('Pretty Pictures', [15, 1, 15]),
#  ('ArtÃ©mis Productions', [15, 1, 15]),
#  ('Le Tax Shelter du Gouvernement FÃ©dÃ©ral de Belgique', [15, 1, 15]),
#  ('Taxshelter. be', [15, 1, 15]),
#  ('Iron Horse Entertainment (II)', [30, 2, 15.0]),
#  ('Venture Forth', [15, 1, 15]),
#  ('Dayday Films', [15, 1, 15]),
#  ('Mad Chance Productions', [15, 1, 15]),
#  ('Aldamisa Entertainment', [45, 3, 15.0]),
#  ('Before the Door Pictures', [30, 2, 15.0]),
#  ('Washington Square Films', [30, 2, 15.0]),
#  ('LBI Productions', [15, 1, 15]),
#  ('Hopscotch Films', [15, 1, 15]),
#  ('Provident Films', [15, 1, 15]),
#  ('FourBoys Entertainment', [15, 1, 15]),
#  ('Panorama Films', [15, 1, 15]),
#  ('Curse Productions', [15, 1, 15]),
#  ('Bernard Gayle Productions', [15, 1, 15]),
#  ('Saga Film', [15, 1, 15]),
#  ('Chambara Pictures', [15, 1, 15]),
#  ('CinemaNX', [30, 2, 15.0]),
#  ('Firm Films', [90, 6, 15.0]),
#  ('Rice Films', [15, 1, 15]),
#  ('Battle Mountain Films', [15, 1, 15]),
#  ('American Film Company', [15, 1, 15]),
#  ('Lions Gate Family Entertainment', [15, 1, 15]),
#  ('Crest Animation Productions', [15, 1, 15]),
#  ('Furry Vengeance Productions', [15, 1, 15]),
#  ('Black and Blu Entertainment', [15, 1, 15]),
#  ('Finestkind', [15, 1, 15]),
#  ('Intermedia Films', [180, 12, 15.0]),
#  ('Ufland', [15, 1, 15]),
#  ('Eon Productions', [45, 3, 15.0]),
#  ('Hypnotic', [45, 3, 15.0]),
#  ('Kingsgate Films', [15, 1, 15]),
#  ('Voltage Pictures', [45, 3, 15.0]),
#  ('Film Capital Europe Funds (FCEF )', [15, 1, 15]),
#  ('Baumgarten Management and Productions (BMP)', [15, 1, 15]),
#  ('Alta Loma Entertainment', [15, 1, 15]),
#  ('Random Films', [15, 1, 15]),
#  ('LBI Entertainment', [15, 1, 15]),
#  ('Ad Hominem Enterprises', [15, 1, 15]),
#  ('Aura Film Partnership', [15, 1, 15]),
#  ('Kalima Productions GmbH & Co. KG', [45, 3, 15.0]),
#  ('TF1 Films Productions', [15, 1, 15]),
#  ('Sea Breeze Productions Inc.', [15, 1, 15]),
#  ('Marty Katz Productions', [45, 3, 15.0]),
#  ('Clear Blue Sky Productions', [15, 1, 15]),
#  ('CAMERON MACKINTOSH', [15, 1, 15]),
#  ('RabbitBandini Productions', [15, 1, 15]),
#  ('Division Films', [15, 1, 15]),
#  ('Pop Films', [15, 1, 15]),
#  ('Muse Productions', [30, 2, 15.0]),
#  ('Millenium Films', [15, 1, 15]),
#  ('Two Ton Films', [30, 2, 15.0]),
#  ('Silver Bullet Productions (II)', [15, 1, 15]),
#  ('Blind Wink Productions', [15, 1, 15]),
#  ('Archer Street Productions', [15, 1, 15]),
#  ('Latitude Media', [15, 1, 15]),
#  ('Mile High Productions', [15, 1, 15]),
#  ('Kevin Messick Productions', [15, 1, 15]),
#  ('Hit & Run Productions', [15, 1, 15]),
#  ('Contagious Entertainment', [15, 1, 15]),
#  ('Sunset Gower Studios', [15, 1, 15]),
#  ('Clifford Werber Productions', [30, 2, 15.0]),
#  ('Fellowship Adventure Group', [15, 1, 15]),
#  ('AR-TL', [15, 1, 15]),
#  ('Wendy Finerman Productions', [15, 1, 15]),
#  ('Tiger Aspect Productions', [30, 2, 15.0]),
#  ('Zadan / Meron Productions', [15, 1, 15]),
#  ('ETIC Films', [15, 1, 15]),
#  ('Wind Dancer Productions', [15, 1, 15]),
#  ('Red Horizon Productions', [15, 1, 15]),
#  ('Double Feature Films', [149, 10, 14.9]),
#  ('Universal Studios', [89, 6, 14.833333333333334]),
#  ('Silver Pictures', [252, 17, 14.823529411764707]),
#  ('Summit Entertainment', [607, 41, 14.804878048780488]),
#  ('Lionsgate', [518, 35, 14.8]),
#  ('Columbia Pictures Corporation', [695, 47, 14.787234042553191]),
#  ('Waverly Films', [59, 4, 14.75]),
#  ('Josephson Entertainment', [59, 4, 14.75]),
#  ('Kanzaman', [59, 4, 14.75]),
#  ('Columbia Pictures', [1722, 117, 14.717948717948717]),
#  ('Universal Pictures', [2546, 173, 14.716763005780347]),
#  ('Jersey Films', [88, 6, 14.666666666666666]),
#  ('Conundrum Entertainment', [88, 6, 14.666666666666666]),
#  ('Atlas Entertainment', [88, 6, 14.666666666666666]),
#  ('Fox Searchlight', [44, 3, 14.666666666666666]),
#  ('Major Studio Partners', [88, 6, 14.666666666666666]),
#  ('Screen Gems', [454, 31, 14.64516129032258]),
#  ('Marc Platt Productions', [146, 10, 14.6]),
#  ('Mad Chance', [73, 5, 14.6]),
#  ('Lawrence Bender Productions', [73, 5, 14.6]),
#  ('Lions Gate Films', [277, 19, 14.578947368421053]),
#  ('Davis Entertainment', [262, 18, 14.555555555555555]),
#  ('Living Films', [29, 2, 14.5]),
#  ('Don Carmody Productions', [58, 4, 14.5]),
#  ('Pure Flix Entertainment', [29, 2, 14.5]),
#  ('Aegis Film Fund', [29, 2, 14.5]),
#  ('Jerry Weintraub Productions', [58, 4, 14.5]),
#  ('Maguire Entertainment', [29, 2, 14.5]),
#  ('Morgan Creek Productions', [174, 12, 14.5]),
#  ("Mel's Cite du Cinema", [87, 6, 14.5]),
#  ('China Film Group Corporation (CFGC)', [29, 2, 14.5]),
#  ('Birnbaum / Barber Productions', [29, 2, 14.5]),
#  ('Mandalay Pictures', [101, 7, 14.428571428571429]),
#  ('Scott Free Productions', [344, 24, 14.333333333333334]),
#  ('Big Kid Pictures', [43, 3, 14.333333333333334]),
#  ('Olive Bridge Entertainment', [43, 3, 14.333333333333334]),
#  ('Internationale Filmproduktion Blackbird Dritte',
#   [43, 3, 14.333333333333334]),
#  ('Gerber Pictures', [43, 3, 14.333333333333334]),
#  ('Cheetah Vision', [43, 3, 14.333333333333334]),
#  ('Mirage Enterprises', [43, 3, 14.333333333333334]),
#  ('Film4', [186, 13, 14.307692307692308]),
#  ('Escape Artists', [186, 13, 14.307692307692308]),
#  ('Dimension Films', [529, 37, 14.297297297297296]),
#  ('Contrafilm', [100, 7, 14.285714285714286]),
#  ('Participant Media', [214, 15, 14.266666666666667]),
#  ('CBS Films', [142, 10, 14.2]),
#  ('One Race Productions', [71, 5, 14.2]),
#  ('NPV Entertainment', [283, 20, 14.15]),
#  ('Chernin Entertainment', [99, 7, 14.142857142857142]),
#  ('The Weinstein Company', [393, 28, 14.035714285714286]),
#  ('Kennedy Miller Productions', [28, 2, 14.0]),
#  ('NeoReel', [42, 3, 14.0]),
#  ('Focus Features', [294, 21, 14.0]),
#  ('Brownstone Productions', [28, 2, 14.0]),
#  ('Versus Pictures', [14, 1, 14]),
#  ('Constantin Film.', [14, 1, 14]),
#  ('Raindog Films', [14, 1, 14]),
#  ('Onyx Films', [28, 2, 14.0]),
#  ('Amazon Studios', [14, 1, 14]),
#  ('Film Art Media', [14, 1, 14]),
#  ('Apollo Media', [14, 1, 14]),
#  ('Dune Films', [56, 4, 14.0]),
#  ('Lucamar Productions', [14, 1, 14]),
#  ('Cannell Studios', [14, 1, 14]),
#  ('Karz Entertainment', [70, 5, 14.0]),
#  ('Ghoulardi Film Company', [42, 3, 14.0]),
#  ('Screen Queensland', [14, 1, 14]),
#  ('Blacklab Entertainment', [14, 1, 14]),
#  ('Wolfhound Pictures', [14, 1, 14]),
#  ('Electronic Arts', [14, 1, 14]),
#  ('D8', [14, 1, 14]),
#  ('Screen Gems, Inc.', [28, 2, 14.0]),
#  ('Creative Scotland', [14, 1, 14]),
#  ('Boxing Cat Films', [28, 2, 14.0]),
#  ('Green Hat Films', [70, 5, 14.0]),
#  ('Left Tackle Pictures', [14, 1, 14]),
#  ('Zucker/Netter Productions', [14, 1, 14]),
#  ('Palomar Pictures (II)', [28, 2, 14.0]),
#  ('Andell Entertainment', [28, 2, 14.0]),
#  ('Jaffe / Braunstein Enterprise', [14, 1, 14]),
#  ('X-Filme Creative Pool', [28, 2, 14.0]),
#  ('Dentsu Inc.', [14, 1, 14]),
#  ('Spectacle Entertainment Group', [42, 3, 14.0]),
#  ('Dreamworks Pictures', [14, 1, 14]),
#  ('Pink Machine', [14, 1, 14]),
#  ('China Film Group', [14, 1, 14]),
#  ('Reliance BIG Entertainment', [56, 4, 14.0]),
#  ('Gracie Films', [42, 3, 14.0]),
#  ('PVR Cinemas', [14, 1, 14]),
#  ('Hari Om Entertainment Co.', [14, 1, 14]),
#  ('Blockbuster Movie Entertainers', [14, 1, 14]),
#  ('Liveplanet', [14, 1, 14]),
#  ('Storm King Productions', [14, 1, 14]),
#  ('Animationwerks', [14, 1, 14]),
#  ('Dan Films', [14, 1, 14]),
#  ('CP Medien AG', [14, 1, 14]),
#  ('Internationale Filmproduktion Stella-del-Sud Second', [14, 1, 14]),
#  ('InVenture Entertainment', [14, 1, 14]),
#  ('Nu-Image Films', [14, 1, 14]),
#  ('Deep River Productions', [28, 2, 14.0]),
#  ('3 in the Box', [14, 1, 14]),
#  ('Participant Productions', [28, 2, 14.0]),
#  ('Dr D Studios', [14, 1, 14]),
#  ('Kennedy Miller Mitchell', [14, 1, 14]),
#  ('Out of the Blue... Entertainment', [28, 2, 14.0]),
#  ('Catch 23 Entertainment', [14, 1, 14]),
#  ('Stephen J. Cannell Productions', [14, 1, 14]),
#  ('Di Bonaventura Picture', [14, 1, 14]),
#  ('North Box Productions', [14, 1, 14]),
#  ('Mandalay Vision', [14, 1, 14]),
#  ('Studio Babelsberg Motion Pictures', [14, 1, 14]),
#  ('Pit Bull Productions', [14, 1, 14]),
#  ('Mediastream Dritte Film', [14, 1, 14]),
#  ('Harbour Pictures', [14, 1, 14]),
#  ('SOIXAN7E QUIN5E', [14, 1, 14]),
#  ('See Me Louisiana', [14, 1, 14]),
#  ('Langley Park Production', [14, 1, 14]),
#  ('Aggregate Films', [14, 1, 14]),
#  ('DumbDumb', [14, 1, 14]),
#  ('PathÃ© Distribution', [14, 1, 14]),
#  ('Company Films', [14, 1, 14]),
#  ('Dalian Wanda Group', [14, 1, 14]),
#  ('Kumar Mobiliengesellschaft mbH & Co. Projekt Nr. 3 KG', [14, 1, 14]),
#  ('Parkway Pictures (I)', [14, 1, 14]),
#  ('Five Roses', [14, 1, 14]),
#  ('Sound for Film', [14, 1, 14]),
#  ('Universal Animation Studios', [14, 1, 14]),
#  ('True Grit Productions', [14, 1, 14]),
#  ('Zero Gravity Management', [14, 1, 14]),
#  ('Pierce/Williams Entertainment', [14, 1, 14]),
#  ('Shawn Danielle Productions Ltd.', [14, 1, 14]),
#  ('Thirteen Productions', [14, 1, 14]),
#  ('Taormina Productions', [14, 1, 14]),
#  ('Sociedad General de Cine S.A.', [14, 1, 14]),
#  ('Entertainment Films', [14, 1, 14]),
#  ('Material Entertainment', [14, 1, 14]),
#  ('Beech Hill Films', [14, 1, 14]),
#  ('Underground', [14, 1, 14]),
#  ('Brass Hat Films', [14, 1, 14]),
#  ('Dreamachine', [14, 1, 14]),
#  ('Cruella Productions', [14, 1, 14]),
#  ('SNL Studios', [14, 1, 14]),
#  ('Happy Madison Productions', [320, 23, 13.91304347826087]),
#  ('DreamWorks SKG', [862, 62, 13.903225806451612]),
#  ('Spyglass Entertainment', [444, 32, 13.875]),
#  ('France 2 CinÃ©ma', [83, 6, 13.833333333333334]),
#  ('Marv Films', [69, 5, 13.8]),
#  ('Robert Simonds Productions', [138, 10, 13.8]),
#  ('Bel Air Entertainment', [69, 5, 13.8]),
#  ('Touchstone Pictures', [800, 58, 13.793103448275861]),
#  ('Exclusive Media Group', [124, 9, 13.777777777777779]),
#  ('Franchise Pictures', [179, 13, 13.76923076923077]),
#  ('Alliance Films', [55, 4, 13.75]),
#  ('Icon Productions', [55, 4, 13.75]),
#  ('Brightlight Pictures', [55, 4, 13.75]),
#  ('Troublemaker Studios', [96, 7, 13.714285714285714]),
#  ('DNA Films', [137, 10, 13.7]),
#  ('Phoenix Pictures', [123, 9, 13.666666666666666]),
#  ('StudioCanal', [313, 23, 13.608695652173912]),
#  ('Wild West Picture Show Productions', [68, 5, 13.6]),
#  ('Atmosphere Entertainment MM', [95, 7, 13.571428571428571]),
#  ('Dentsu', [162, 12, 13.5]),
#  ('Fox International Productions', [27, 2, 13.5]),
#  ('Ruby Films', [27, 2, 13.5]),
#  ('Albert S. Ruddy Productions', [27, 2, 13.5]),
#  ('Inferno Distribution', [27, 2, 13.5]),
#  ('Road Rebel', [27, 2, 13.5]),
#  ('Hammer Film Productions', [27, 2, 13.5]),
#  ('Red Wagon Productions', [27, 2, 13.5]),
#  ('David Brown Productions', [27, 2, 13.5]),
#  ('Hal Lieberman Company', [27, 2, 13.5]),
#  ('Anonymous Content', [148, 11, 13.454545454545455]),
#  ('United Artists', [121, 9, 13.444444444444445]),
#  ('Legendary Pictures', [456, 34, 13.411764705882353]),
#  ('Regency Enterprises', [657, 49, 13.408163265306122]),
#  ('Anarchos Productions', [67, 5, 13.4]),
#  ('3 Arts Entertainment', [67, 5, 13.4]),
#  ('Syncopy', [107, 8, 13.375]),
#  ('Point Grey Pictures', [40, 3, 13.333333333333334]),
#  ('Offspring Entertainment', [80, 6, 13.333333333333334]),
#  ('HanWay Films', [40, 3, 13.333333333333334]),
#  ('De Line Pictures', [120, 9, 13.333333333333334]),
#  ('Bedford Falls Productions', [40, 3, 13.333333333333334]),
#  ('World 2000 Entertainment', [40, 3, 13.333333333333334]),
#  ('Universal', [40, 3, 13.333333333333334]),
#  ('Relativity Media', [1313, 99, 13.262626262626263]),
#  ('Shangri-La Entertainment', [53, 4, 13.25]),
#  ('Treehouse Pictures', [53, 4, 13.25]),
#  ('Grindstone Entertainment Group', [53, 4, 13.25]),
#  ('Ecosse Films', [53, 4, 13.25]),
#  ('Avery Pix', [53, 4, 13.25]),
#  ('Reliance Entertainment', [105, 8, 13.125]),
#  ('EuropaCorp', [223, 17, 13.117647058823529]),
#  ('Original Film', [380, 29, 13.10344827586207]),
#  ('Sony Pictures Entertainment', [52, 4, 13.0]),
#  ('BenderSpink', [104, 8, 13.0]),
#  ('RatPac Entertainment', [39, 3, 13.0]),
#  ('Mace Neufeld Productions', [52, 4, 13.0]),
#  ('Province of British Columbia Production Services Tax Credit',
#   [78, 6, 13.0]),
#  ('Malpaso Productions', [156, 12, 13.0]),
#  ('Straight Up Films', [13, 1, 13]),
#  ('Bandito Brothers', [26, 2, 13.0]),
#  ('Broken Road Productions', [65, 5, 13.0]),
#  ('Warner Bros. Interactive Entertainment', [13, 1, 13]),
#  ('Rob Thomas Productions', [13, 1, 13]),
#  ('Panay Films', [13, 1, 13]),
#  ('Key Creatives', [26, 2, 13.0]),
#  ('Wintergreen Productions', [65, 5, 13.0]),
#  ('2929 Productions', [78, 6, 13.0]),
#  ('Easy There Tiger Productions', [13, 1, 13]),
#  ('Pictures in Paradise', [26, 2, 13.0]),
#  ('Mosaic Media Group', [130, 10, 13.0]),
#  ('Tree Line Films', [39, 3, 13.0]),
#  ('Red Om Films', [13, 1, 13]),
#  ('Madhouse Entertainment', [26, 2, 13.0]),
#  ('Brad Grey Pictures', [52, 4, 13.0]),
#  ('Metropolitan Filmexport', [52, 4, 13.0]),
#  ('Crystal Sky Worldwide', [13, 1, 13]),
#  ('MDP Worldwide', [13, 1, 13]),
#  ('Carousel Picture Company, The', [13, 1, 13]),
#  ('Signature Entertainment', [13, 1, 13]),
#  ('Europa Corp', [13, 1, 13]),
#  ('Art In Motion', [13, 1, 13]),
#  ('Blueprint Pictures', [26, 2, 13.0]),
#  ('Internationale Filmproduktion', [13, 1, 13]),
#  ('Lietuvos Kinostudija', [13, 1, 13]),
#  ('Scout Productions', [13, 1, 13]),
#  ('Castelao Producciones', [26, 2, 13.0]),
#  ('Ascendant Pictures', [39, 3, 13.0]),
#  ('UTV Motion Pictures', [13, 1, 13]),
#  ('Blue Tulip Productions', [26, 2, 13.0]),
#  ('Initial Entertainment Group (IEG)', [65, 5, 13.0]),
#  ('Hungry Eye Lowland Pictures B.V.', [13, 1, 13]),
#  ('Flan de Coco Films', [13, 1, 13]),
#  ('Tripod Entertainment', [13, 1, 13]),
#  ('Media Farm', [13, 1, 13]),
#  ('Sunday Night', [13, 1, 13]),
#  ('TÃ©lÃ©film Canada', [26, 2, 13.0]),
#  ('Cattleya', [13, 1, 13]),
#  ('FidÃ©litÃ© Productions', [13, 1, 13]),
#  ('Gimages', [13, 1, 13]),
#  ('FOZ', [13, 1, 13]),
#  ('Herrick Entertainment', [13, 1, 13]),
#  ('Stone Village Pictures', [13, 1, 13]),
#  ('Sneak Preview Productions', [13, 1, 13]),
#  ('TF 1 Film Productions', [13, 1, 13]),
#  ('MBC Beteiligungs Filmproduktion', [13, 1, 13]),
#  ('Catfish Productions', [13, 1, 13]),
#  ('Tiara Blu Films', [13, 1, 13]),
#  ('Blackfriars Bridge Films', [26, 2, 13.0]),
#  ('Grand Slam Productions', [13, 1, 13]),
#  ('Filmax Entertainment', [13, 1, 13]),
#  ('ICF', [13, 1, 13]),
#  ('Visual Arts Entertainment', [13, 1, 13]),
#  ('Into the Wild', [13, 1, 13]),
#  ('Monkey Dance Productions', [13, 1, 13]),
#  ('Bueprint Pictures', [13, 1, 13]),
#  ('Sunlight Productions', [13, 1, 13]),
#  ('Madison 23', [13, 1, 13]),
#  ('Clipsal Films', [13, 1, 13]),
#  ("Donners' Company", [116, 9, 12.88888888888889]),
#  ('Centropolis Entertainment', [77, 6, 12.833333333333334]),
#  ('Epsilon Motion Pictures', [308, 24, 12.833333333333334]),
#  ('Sony Pictures', [64, 5, 12.8]),
#  ('Isle of Man Film', [64, 5, 12.8]),
#  ('Moonlighting Films', [51, 4, 12.75]),
#  ('Bona Fide Productions', [51, 4, 12.75]),
#  ('Quinta Communications', [51, 4, 12.75]),
#  ('Paramount Vantage', [127, 10, 12.7]),
#  ('Fuji Television Network', [38, 3, 12.666666666666666]),
#  ('Peninsula Films', [38, 3, 12.666666666666666]),
#  ('Bazmark Films', [38, 3, 12.666666666666666]),
#  ('Art Linson Productions', [38, 3, 12.666666666666666]),
#  ('Baldwin Entertainment Group', [38, 3, 12.666666666666666]),
#  ('Cheyenne Enterprises', [101, 8, 12.625]),
#  ('New Regency Pictures', [353, 28, 12.607142857142858]),
#  ('Laura Ziskin Productions', [63, 5, 12.6]),
#  ('Stuber Productions', [88, 7, 12.571428571428571]),
#  ('Rogue Pictures', [113, 9, 12.555555555555555]),
#  ('Twentieth Century Fox Animation', [125, 10, 12.5]),
#  ...]

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %%
answers['25']='3. Midnight Picture Show' #+

words_overview={}
for row in zip(data['production_companies'],data['words_overview']):
    for studio in row[0].split('|'):
        if(words_overview.setdefault(studio)  == None):
            words_overview[studio]=[row[1],1,row[1]]
        else:
            words_overview[studio][0] += row[1] #суммируем длины описаний
            words_overview[studio][1] += 1 # сохраняем количество фильмов студии
            words_overview[studio][2] = words_overview[studio][0]/words_overview[studio][1] # сразу считаем среднюю длину описания
sorted(words_overview.items(), key=lambda item: item[1][2], reverse=True)
# Out:
# [('Midnight Picture Show', [175, 1, 175]),
#  ('Heineken Branded Entertainment', [161, 1, 161]),
#  ('Room 9 Entertainment', [161, 1, 161]),
#  ('98 MPH Productions', [159, 1, 159]),
#  ('Brookwell-McNamara Entertainment', [156, 1, 156]),
#  ('Lions Gate Family Entertainment', [152, 1, 152]),
#  ('Crest Animation Productions', [152, 1, 152]),
#  ('Art Pictures Studio', [147, 1, 147]),
#  ('Starbucks Entertainment', [144, 1, 144]),
#  ('Cinema Gypsy Productions', [144, 1, 144]),
#  ('Wayfare Entertainment', [138, 1, 138]),
#  ('Sanctum Australia', [138, 1, 138]),
#  ('Great Wight Productions/ Osford Films', [138, 1, 138]),
#  ('Sudden Storm Productions', [134, 1, 134]),
#  ('Magical Elves Productions', [132, 1, 132]),
#  ('Scooter Braun Films', [132, 1, 132]),
#  ('Disney Double Dare You (DDY)', [130, 1, 130]),
#  ('K. JAM Media', [128, 1, 128]),
#  ('Radical Studios', [255, 2, 127.5]),
#  ('Silent Hill DCP Inc.', [126, 1, 126]),
#  ('Konami', [126, 1, 126]),
#  ('Oceana Media Finance', [122, 1, 122]),
#  ('Pantheon Entertainment Corporation', [122, 1, 122]),
#  ('Innocence Productions', [122, 1, 122]),
#  ('Omega Entertainment', [122, 1, 122]),
#  ('David Ladd Films', [239, 2, 119.5]),
#  ('O.N.C. Entertainment', [117, 1, 117]),
#  ('Ten Thirteen Productions', [116, 1, 116]),
#  ('Crying Box Productions', [116, 1, 116]),
#  ('Red Om Films', [115, 1, 115]),
#  ('Ex3 Productions', [113, 1, 113]),
#  ('Liberty Films UK', [113, 1, 113]),
#  ('Lunar Industries', [113, 1, 113]),
#  ('Xingu Films', [113, 1, 113]),
#  ('Limelight Fund', [113, 1, 113]),
#  ('Double Nickel Entertainment', [113, 1, 113]),
#  ('Cappa Productions', [113, 1, 113]),
#  ('Broken Chair Flickz', [112, 1, 112]),
#  ('Panay Films', [111, 1, 111]),
#  ('Esperanto Filmoj', [111, 1, 111]),
#  ('Langley Park Production', [111, 1, 111]),
#  ('Darlow Smithson Productions', [109, 1, 109]),
#  ('Alta Loma Entertainment', [108, 1, 108]),
#  ('Varsity Pictures', [108, 1, 108]),
#  ('Andalasia Productions', [108, 1, 108]),
#  ('Right Coast Productions', [108, 1, 108]),
#  ('Farewell Productions', [107, 1, 107]),
#  ('China Film Group', [107, 1, 107]),
#  ('Yash Raj Films', [107, 1, 107]),
#  ('Hemisphere Media Capital', [319, 3, 106.33333333333333]),
#  ('New Upstairs Productions', [106, 1, 106]),
#  ('Upstairs Canada Productions', [106, 1, 106]),
#  ('FidÃ©litÃ© Films', [106, 1, 106]),
#  ('Hwy61', [106, 1, 106]),
#  ('Front Street Productions', [105, 1, 105]),
#  ('Spitfire Pictures', [105, 1, 105]),
#  ('Walt Disney Studios Motion Pictures', [312, 3, 104.0]),
#  ('Stone Productions', [104, 1, 104]),
#  ('Mimran Schur Pictures', [104, 1, 104]),
#  ('Davis-Panzer Productions', [104, 1, 104]),
#  ('Vidhu Vinod Chopra Productions', [103, 1, 103]),
#  ('Out of the Blue... Entertainment', [206, 2, 103.0]),
#  ('Cube Vision', [306, 3, 102.0]),
#  ('Darko Entertainment', [102, 1, 102]),
#  ('Gaylord Films', [101, 1, 101]),
#  ('Bird and a Bear Entertainment', [101, 1, 101]),
#  ('Hallway Pictures', [101, 1, 101]),
#  ('Catch Productions', [101, 1, 101]),
#  ('MacDonald/Parkes Productions', [200, 2, 100.0]),
#  ('Before the Door Pictures', [199, 2, 99.5]),
#  ('Washington Square Films', [199, 2, 99.5]),
#  ('Kerner Entertainment Company', [198, 2, 99.0]),
#  ('Brownstone Productions', [196, 2, 98.0]),
#  ('Y Productions', [98, 1, 98]),
#  ('Mediana Productions Filmgesellschaft', [98, 1, 98]),
#  ('Flynn Picture Company', [195, 2, 97.5]),
#  ('Cannell Studios', [97, 1, 97]),
#  ('Rice Films', [97, 1, 97]),
#  ('Trackform Film Productions', [97, 1, 97]),
#  ('Random Films', [97, 1, 97]),
#  ('Rhythm and Hues', [96, 1, 96]),
#  ('Picnic Basket', [96, 1, 96]),
#  ('Bay Films', [96, 1, 96]),
#  ('Lip Sync Post', [96, 1, 96]),
#  ('Trademark Films', [96, 1, 96]),
#  ('Mark Johnson Productions', [95, 1, 95]),
#  ('Curmudgeon Films', [95, 1, 95]),
#  ('New Redemption Pictures', [95, 1, 95]),
#  ('Fastnet Films', [95, 1, 95]),
#  ('Caramel Film', [95, 1, 95]),
#  ('Helena Productions', [95, 1, 95]),
#  ("It's a Laugh Productions", [94, 1, 94]),
#  ('Millar Gough Ink', [94, 1, 94]),
#  ('Storm King Productions', [94, 1, 94]),
#  ('Animationwerks', [94, 1, 94]),
#  ('Josephson Entertainment', [374, 4, 93.5]),
#  ('NeoReel', [280, 3, 93.33333333333333]),
#  ('Film 44', [93, 1, 93]),
#  ('Qwerty Films', [92, 1, 92]),
#  ('TF1 Droits Audiovisuels', [92, 1, 92]),
#  ('Pioneer Pictures', [92, 1, 92]),
#  ('LBI Entertainment', [92, 1, 92]),
#  ('Ascension Pictures', [92, 1, 92]),
#  ('ARD Degeto Film', [92, 1, 92]),
#  ('Cloud Atlas Productions', [92, 1, 92]),
#  ('Pinewood Studios', [92, 1, 92]),
#  ('Metrol Technology', [92, 1, 92]),
#  ('Alpha Core', [183, 2, 91.5]),
#  ('Gerber Pictures', [274, 3, 91.33333333333333]),
#  ('Indochina Productions', [181, 2, 90.5]),
#  ('Nickelodeon Animation Studios', [90, 1, 90]),
#  ('United Plankton Pictures', [90, 1, 90]),
#  ('Sony', [90, 1, 90]),
#  ('Media Magik Entertainment', [179, 2, 89.5]),
#  ('Internationale Filmproduktion Stella-del-Sud Second', [89, 1, 89]),
#  ('Bedford Falls Productions', [265, 3, 88.33333333333333]),
#  ('Talisman Productions', [88, 1, 88]),
#  ('Perdido Productions', [88, 1, 88]),
#  ('Toledo Productions', [87, 1, 87]),
#  ('Rena Film', [87, 1, 87]),
#  ('Peach Trees', [87, 1, 87]),
#  ('Disney Enterprises', [87, 1, 87]),
#  ('NuAmerica Entertainment', [87, 1, 87]),
#  ('Reiner-Greisman', [87, 1, 87]),
#  ('Troika Pictures', [87, 1, 87]),
#  ('Emergency Films', [87, 1, 87]),
#  ('Apotheosis Media Group', [87, 1, 87]),
#  ('Dutch Oven', [87, 1, 87]),
#  ('New Regency Productions', [87, 1, 87]),
#  ('Compulsion Inc.', [87, 1, 87]),
#  ('Splendid Medien AG', [87, 1, 87]),
#  ('Mad Hatter Entertainment', [172, 2, 86.0]),
#  ('Tooley Productions', [86, 1, 86]),
#  ('Total Entertainment', [86, 1, 86]),
#  ('TSBD Canada Productions', [86, 1, 86]),
#  ('Zohar International', [86, 1, 86]),
#  ('Monolith Pictures (III)', [86, 1, 86]),
#  ('LStar Capital', [513, 6, 85.5]),
#  ('Storefront Films', [85, 1, 85]),
#  ('Michael Lobell Productions', [85, 1, 85]),
#  ('Edmonds Entertainment Group (EEG)', [84, 1, 84]),
#  ('Epidemic Pictures', [84, 1, 84]),
#  ('Lauren Levine Productions Inc.', [84, 1, 84]),
#  ('David Foster Productions', [250, 3, 83.33333333333333]),
#  ('Mad Chance Productions', [83, 1, 83]),
#  ('Fireworks Pictures', [83, 1, 83]),
#  ('The Ladd Company', [166, 2, 83.0]),
#  ('Samuelson Productions', [83, 1, 83]),
#  ('Emperor Motion Pictures', [165, 2, 82.5]),
#  ('Hollywood Pictures', [165, 2, 82.5]),
#  ('Avi Arad Productions', [82, 1, 82]),
#  ('Matt Tolmach Productions', [82, 1, 82]),
#  ('Pendle Mountain Productions', [82, 1, 82]),
#  ('Octagon Films', [82, 1, 82]),
#  ('Birnbaum/Barber', [82, 1, 82]),
#  ('The Javelina Film Company', [82, 1, 82]),
#  ('Roth Films', [573, 7, 81.85714285714286]),
#  ('Reliance BIG Entertainment', [326, 4, 81.5]),
#  ('Bedlam Productions', [81, 1, 81]),
#  ('See-Saw Films', [81, 1, 81]),
#  ('Chako Film Company', [81, 1, 81]),
#  ('MBC Beteiligungs Filmproduktion', [81, 1, 81]),
#  ('Parkes/MacDonald Productions', [323, 4, 80.75]),
#  ('China Film Co-Production Corporation', [321, 4, 80.25]),
#  ('DefyNite Films', [80, 1, 80]),
#  ('MJW Films', [80, 1, 80]),
#  ('Constantin Film International', [80, 1, 80]),
#  ('Ozla Pictures', [80, 1, 80]),
#  ('Hammer Film Productions', [160, 2, 80.0]),
#  ('Greenestreet Films', [80, 1, 80]),
#  ('Witness Protection Films', [80, 1, 80]),
#  ('Paco Cinematografica', [80, 1, 80]),
#  ('Regione Lazio', [80, 1, 80]),
#  ('Business Location Sudtirol Alto Adige', [80, 1, 80]),
#  ('Friuli Venezia Giulia Film Commission', [80, 1, 80]),
#  ('Shawn Danielle Productions Ltd.', [80, 1, 80]),
#  ('Insurge Pictures', [239, 3, 79.66666666666667]),
#  ('WV Films III', [239, 3, 79.66666666666667]),
#  ('Village Roadshow Pictures Asia', [79, 1, 79]),
#  ('Ott Medien', [79, 1, 79]),
#  ('Millenium Films', [79, 1, 79]),
#  ('Reaper Productions', [79, 1, 79]),
#  ('Lucasfilm', [313, 4, 78.25]),
#  ('Prime Focus', [156, 2, 78.0]),
#  ('Goldmann Pictures', [234, 3, 78.0]),
#  ('LionsGate', [156, 2, 78.0]),
#  ('Case 39 Productions', [78, 1, 78]),
#  ('SGF Entertainment', [78, 1, 78]),
#  ('Province of British Columbia Film Incentive BC', [78, 1, 78]),
#  ('Cattleya', [78, 1, 78]),
#  ('Riddick Canada Productions', [78, 1, 78]),
#  ('Raygun Productions', [78, 1, 78]),
#  ('Rosey Film Productions LLC', [78, 1, 78]),
#  ('I Remember Productions', [78, 1, 78]),
#  ('FilmDistrict', [545, 7, 77.85714285714286]),
#  ('Aardman Animations', [311, 4, 77.75]),
#  ('Team Todd', [233, 3, 77.66666666666667]),
#  ('Parkes+MacDonald Image Nation', [232, 3, 77.33333333333333]),
#  ('Dreamworks Pictures', [77, 1, 77]),
#  ('Matador Pictures', [77, 1, 77]),
#  ('Magic Light Pictures', [77, 1, 77]),
#  ('Cinema Four', [77, 1, 77]),
#  ('Milagro Films', [77, 1, 77]),
#  ('DoRo Fiction Film', [77, 1, 77]),
#  ('Cott Productions', [77, 1, 77]),
#  ('Furia de Titanes II, A.I.E.', [77, 1, 77]),
#  ('Akil Production Company', [77, 1, 77]),
#  ('Mythology Entertainment (II)', [77, 1, 77]),
#  ('Clubdeal', [77, 1, 77]),
#  ('Harlequin Pictures', [77, 1, 77]),
#  ('Intertainment AG', [77, 1, 77]),
#  ('Blackout Productions Inc.', [77, 1, 77]),
#  ('Universal Pictures International (UPI)', [76, 1, 76]),
#  ('Riche-Ludwig Productions', [76, 1, 76]),
#  ('Apaches Entertainment', [76, 1, 76]),
#  ('Unique Features', [76, 1, 76]),
#  ('Mr. Smith Productions', [76, 1, 76]),
#  ('Sociedad General de Cine S.A.', [76, 1, 76]),
#  ('Initial Entertainment Group (IEG)', [378, 5, 75.6]),
#  ("Mel's Cite du Cinema", [452, 6, 75.33333333333333]),
#  ('Electronic Arts', [75, 1, 75]),
#  ('D8', [75, 1, 75]),
#  ('MavroCine Pictures GmbH & Co. KG', [75, 1, 75]),
#  ('X-Filme Creative Pool', [150, 2, 75.0]),
#  ('Three Strange Angels', [225, 3, 75.0]),
#  ('Ozumi Films', [75, 1, 75]),
#  ('Propeler', [75, 1, 75]),
#  ('Serenade Films', [75, 1, 75]),
#  ('Also Known As Pictures', [75, 1, 75]),
#  ('TC Productions', [223, 3, 74.33333333333333]),
#  ('Infinitum Nihil', [370, 5, 74.0]),
#  ('3Foot7', [74, 1, 74]),
#  ('Wild Ocean Films', [74, 1, 74]),
#  ('2S Films', [74, 1, 74]),
#  ('TF1 Films Productions', [74, 1, 74]),
#  ('Jackie Chan Films Limited', [74, 1, 74]),
#  ('All Knight Productions', [74, 1, 74]),
#  ('Hart-Sharp Entertainment', [74, 1, 74]),
#  ('Gone North Productions', [74, 1, 74]),
#  ('Chime Films', [74, 1, 74]),
#  ('Goldcrest Pictures', [515, 7, 73.57142857142857]),
#  ('Winkler Films', [147, 2, 73.5]),
#  ('Type A Films', [147, 2, 73.5]),
#  ('Cliffjack Motion Pictures', [73, 1, 73]),
#  ('Kasdan Pictures', [73, 1, 73]),
#  ('Envision Entertainment Corporation', [146, 2, 73.0]),
#  ('Fine Line Features', [73, 1, 73]),
#  ('Zentropa Entertainments', [73, 1, 73]),
#  ('Danmarks Radio (DR)', [73, 1, 73]),
#  ('SVT Drama', [73, 1, 73]),
#  ('Arte', [73, 1, 73]),
#  ('Rainforest Films', [362, 5, 72.4]),
#  ('No Trace Camping', [144, 2, 72.0]),
#  ('Strike Entertainment', [360, 5, 72.0]),
#  ('EFTI', [72, 1, 72]),
#  ('Native Pictures Productions', [72, 1, 72]),
#  ('GreeneStreet Films', [288, 4, 72.0]),
#  ('WV Films LLC', [72, 1, 72]),
#  ('Apparatus Productions', [72, 1, 72]),
#  ('Two Ton Films', [144, 2, 72.0]),
#  ('Motion Picture KAPPA Produktionsgesellschaft', [72, 1, 72]),
#  ('Failure to Launch Productions', [72, 1, 72]),
#  ('Davis-Films', [718, 10, 71.8]),
#  ('Neal Street Productions', [287, 4, 71.75]),
#  ('Atmosphere Entertainment MM', [502, 7, 71.71428571428571]),
#  ('Imaginary Forces', [143, 2, 71.5]),
#  ('Tapestry Films', [357, 5, 71.4]),
#  ('Viz Media', [71, 1, 71]),
#  ('Obelisk Productions', [71, 1, 71]),
#  ('Laika Entertainment', [284, 4, 71.0]),
#  ('Max Films Productions', [71, 1, 71]),
#  ('Morag Loves Company', [71, 1, 71]),
#  ('Liveplanet', [71, 1, 71]),
#  ('Pistolero Productions LLC', [71, 1, 71]),
#  ('Merlin Films', [71, 1, 71]),
#  ('K/O Camera Toys', [71, 1, 71]),
#  ('Bekmambetov Projects Ltd.', [71, 1, 71]),
#  ('Camelot Pictures', [71, 1, 71]),
#  ('Illusion Entertainment', [71, 1, 71]),
#  ('Mindfire Entertainment', [71, 1, 71]),
#  ('26 Films', [141, 2, 70.5]),
#  ('MHF Zweite Academy Film', [141, 2, 70.5]),
#  ('H2F Entertainment', [141, 2, 70.5]),
#  ('Anton Capital Entertainment (ACE)', [140, 2, 70.0]),
#  ('Prana Animation Studios', [140, 2, 70.0]),
#  ('Seven West Media', [70, 1, 70]),
#  ('Fear of God Films', [70, 1, 70]),
#  ('Seven Group Holdings', [70, 1, 70]),
#  ('Smokewood Entertainment Group', [70, 1, 70]),
#  ('Infinity Features Entertainment', [70, 1, 70]),
#  ('Tezuka Production Company Ltd.', [70, 1, 70]),
#  ('Great Scott Productions Pty. Ltd.', [70, 1, 70]),
#  ('Huayi Brothers', [70, 1, 70]),
#  ('Cohen/Pearl Productions', [70, 1, 70]),
#  ('What to Expect Productions', [70, 1, 70]),
#  ('Mark Gordon Productions', [70, 1, 70]),
#  ('Nancy Tenenbaum Films', [70, 1, 70]),
#  ('Bad Robot', [627, 9, 69.66666666666667]),
#  ('Sony Pictures Animation', [624, 9, 69.33333333333333]),
#  ('The Safran Company', [208, 3, 69.33333333333333]),
#  ('Alliance Films', [277, 4, 69.25]),
#  ('Kennedy Miller Productions', [138, 2, 69.0]),
#  ('Fake Empire', [138, 2, 69.0]),
#  ('The Mark Gordon Company', [276, 4, 69.0]),
#  ('Curse Productions', [69, 1, 69]),
#  ('Omnilab Media', [138, 2, 69.0]),
#  ('Ambience Entertainment', [138, 2, 69.0]),
#  ('Dark Lot Entertainment', [69, 1, 69]),
#  ('UTV Motion Pictures', [69, 1, 69]),
#  ('Moonrise', [69, 1, 69]),
#  ('Triple Threat Talent', [69, 1, 69]),
#  ('Gold Circle Films', [410, 6, 68.33333333333333]),
#  ('Instituto de la CinematografÃ\xada y de las Artes Audiovisuales (ICAA)',
#   [205, 3, 68.33333333333333]),
#  ('Imprint Entertainment', [205, 3, 68.33333333333333]),
#  ('Isle of Man Film', [341, 5, 68.2]),
#  ('Red Hour Productions', [68, 1, 68]),
#  ('Starz Media', [68, 1, 68]),
#  ('Odyssey Entertainment', [136, 2, 68.0]),
#  ('Studiopolis', [68, 1, 68]),
#  ('Vanguard Animation', [68, 1, 68]),
#  ('Jaffilms Inc.', [68, 1, 68]),
#  ('Horsepower Films', [68, 1, 68]),
#  ('Core Productions', [68, 1, 68]),
#  ('Silver Bullet Productions (II)', [68, 1, 68]),
#  ('Blind Wink Productions', [68, 1, 68]),
#  ('Summertime Entertainment', [68, 1, 68]),
#  ('Cineblue Internationale Filmproduktionsgesellschaft', [68, 1, 68]),
#  ('City Productions', [68, 1, 68]),
#  ('Natural Nylon Entertainment', [68, 1, 68]),
#  ('Riff Raff Film Productions', [68, 1, 68]),
#  ('Filmauro', [68, 1, 68]),
#  ('Blue Flower Productions', [68, 1, 68]),
#  ('Really Useful Films', [68, 1, 68]),
#  ('Cranium Films', [68, 1, 68]),
#  ('Nine Yards Productions', [68, 1, 68]),
#  ('Rational Packaging Company', [68, 1, 68]),
#  ('Skydance Productions', [611, 9, 67.88888888888889]),
#  ('Icon Productions', [271, 4, 67.75]),
#  ('One Race Films', [135, 2, 67.5]),
#  ('Hollywood Gang Productions', [135, 2, 67.5]),
#  ('Bluegrass Films', [270, 4, 67.5]),
#  ('KMP Film Invest', [135, 2, 67.5]),
#  ('RatPac-Dune Entertainment', [539, 8, 67.375]),
#  ('Spring Creek Productions', [404, 6, 67.33333333333333]),
#  ('Affirm Films', [202, 3, 67.33333333333333]),
#  ('Overbrook Entertainment', [673, 10, 67.3]),
#  ('Sony Pictures Entertainment (SPE)', [538, 8, 67.25]),
#  ('Nimar Studios', [269, 4, 67.25]),
#  ('Nickelodeon Movies', [938, 14, 67.0]),
#  ('Toho Company', [67, 1, 67]),
#  ('IFP Westcoast Erste', [67, 1, 67]),
#  ('Dentsu Inc.', [67, 1, 67]),
#  ('First Foot Films', [67, 1, 67]),
#  ('TOKYOPOP', [67, 1, 67]),
#  ('Rickshaw Productions', [67, 1, 67]),
#  ('Shutt/Jones Productions', [67, 1, 67]),
#  ('Mediastream Dritte Film', [67, 1, 67]),
#  ('Golden Mean', [67, 1, 67]),
#  ('Universal CGI', [67, 1, 67]),
#  ('QED International', [400, 6, 66.66666666666667]),
#  ('Mid Atlantic Films', [333, 5, 66.6]),
#  ('Energy Entertainment', [133, 2, 66.5]),
#  ('Wayans Bros. Entertainment', [266, 4, 66.5]),
#  ('Hypnotic', [199, 3, 66.33333333333333]),
#  ('Berlanti Productions', [66, 1, 66]),
#  ('Centropolis Entertainment', [396, 6, 66.0]),
#  ('Zanuck Company, The', [198, 3, 66.0]),
#  ('Kemp Company', [66, 1, 66]),
#  ('Hofflund/Polone', [66, 1, 66]),
#  ('Indelible Productions', [66, 1, 66]),
#  ('Ventanarosa Productions', [66, 1, 66]),
#  ('Handprint Entertainment', [66, 1, 66]),
#  ('Burg/Koules Productions', [66, 1, 66]),
#  ('Baltimore Spring Creek Productions', [198, 3, 66.0]),
#  ('Studio Babelsberg Motion Pictures', [66, 1, 66]),
#  ('4M', [66, 1, 66]),
#  ('Iron Film', [66, 1, 66]),
#  ('Gran Via Productions', [329, 5, 65.8]),
#  ('Millennium Films', [1117, 17, 65.70588235294117]),
#  ('Bedford Falls Company, The', [197, 3, 65.66666666666667]),
#  ('Walt Disney', [328, 5, 65.6]),
#  ('Participant Productions', [131, 2, 65.5]),
#  ('Internationale Filmproduktion Blackbird Dritte',
#   [196, 3, 65.33333333333333]),
#  ('Jerry Weintraub Productions', [261, 4, 65.25]),
#  ('Michael De Luca Productions', [391, 6, 65.16666666666667]),
#  ('Runteam Ltd.', [65, 1, 65]),
#  ('R.P. Productions', [65, 1, 65]),
#  ('FilmEngine', [195, 3, 65.0]),
#  ('Tripod Entertainment', [65, 1, 65]),
#  ('40 Acres & A Mule Filmworks', [130, 2, 65.0]),
#  ('Motion Picture THETA Produktionsgesellschaft', [65, 1, 65]),
#  ('Zadan / Meron Productions', [65, 1, 65]),
#  ('GK Films', [714, 11, 64.9090909090909]),
#  ('Amen Ra Films', [259, 4, 64.75]),
#  ('Buckaroo Entertainment', [194, 3, 64.66666666666667]),
#  ('Kurtzman/Orci', [129, 2, 64.5]),
#  ('Twins Financing', [129, 2, 64.5]),
#  ('Evolution Entertainment', [193, 3, 64.33333333333333]),
#  ('Newmarket Capital Group', [257, 4, 64.25]),
#  ('Broken Road Productions', [321, 5, 64.2]),
#  ('Whamaphram Productions', [64, 1, 64]),
#  ('BrownHouse Productions', [64, 1, 64]),
#  ('Bottom of the Ninth Productions', [64, 1, 64]),
#  ('Cinerenta-Cinebeta', [64, 1, 64]),
#  ('VCL Communications', [64, 1, 64]),
#  ('Red Hour Films', [256, 4, 64.0]),
#  ('Top Rope', [64, 1, 64]),
#  ('Konami Corporation Ltd.', [64, 1, 64]),
#  ('Myriad Pictures', [64, 1, 64]),
#  ('Jeepers Creepers II', [64, 1, 64]),
#  ('Eketahuna LLC', [64, 1, 64]),
#  ('HorrorFlix', [64, 1, 64]),
#  ('Tyler Perry Company, The', [64, 1, 64]),
#  ('Cruella Productions', [64, 1, 64]),
#  ('JLT Productions', [64, 1, 64]),
#  ('Escape Artists', [831, 13, 63.92307692307692]),
#  ('Cloud Eight Films', [191, 3, 63.666666666666664]),
#  ('Wonderland Sound and Vision', [318, 5, 63.6]),
#  ('International Traders', [127, 2, 63.5]),
#  ('Nu Image Films', [697, 11, 63.36363636363637]),
#  ('Starz Animation', [190, 3, 63.333333333333336]),
#  ('The Cantillon Company', [63, 1, 63]),
#  ('The Shuman Company', [63, 1, 63]),
#  ('Don Carmody Productions', [252, 4, 63.0]),
#  ('UW3 Film Productions', [63, 1, 63]),
#  ('20th Century Fox Home Entertainment', [63, 1, 63]),
#  ('Midnight Sun Pictures', [63, 1, 63]),
#  ('Bungalow Productions', [63, 1, 63]),
#  ('Silver Lion Films', [63, 1, 63]),
#  ('Vision View Entertainment', [63, 1, 63]),
#  ('Internationale Filmproduktion Richter', [63, 1, 63]),
#  ('Littlestar', [63, 1, 63]),
#  ('Rogue Marble', [126, 2, 63.0]),
#  ('Rifkin-Eberts', [63, 1, 63]),
#  ('Marvel Entertainment, LLC', [63, 1, 63]),
#  ('Milk & Honey', [63, 1, 63]),
#  ('Catch 23 Entertainment', [63, 1, 63]),
#  ('Stephen J. Cannell Productions', [63, 1, 63]),
#  ('Kanbar Entertainment', [63, 1, 63]),
#  ('Blue Yonder Films', [63, 1, 63]),
#  ('Persistent Entertainment', [63, 1, 63]),
#  ('Eclipse Catering', [63, 1, 63]),
#  ('Nine Yards Two Productions', [63, 1, 63]),
#  ('Clipsal Films', [63, 1, 63]),
#  ('Playtone', [251, 4, 62.75]),
#  ('Stars Road Entertainment', [125, 2, 62.5]),
#  ('Chris Lee Productions', [125, 2, 62.5]),
#  ('Pixar Animation Studios', [808, 13, 62.15384615384615]),
#  ('Treehouse Pictures', [248, 4, 62.0]),
#  ('Scope Pictures', [124, 2, 62.0]),
#  ('Evergreen Media Group', [124, 2, 62.0]),
#  ('Yellow Bird', [62, 1, 62]),
#  ('Post No Bills Films', [62, 1, 62]),
#  ('Pandemonium Productions', [62, 1, 62]),
#  ('MMCB Film Produktion 2004', [62, 1, 62]),
#  ('Visual Arts Entertainment', [62, 1, 62]),
#  ('Wind Dancer Productions', [62, 1, 62]),
#  ('Clinica Estetico', [185, 3, 61.666666666666664]),
#  ('Blue Star Pictures', [123, 2, 61.5]),
#  ('Storyline Entertainment', [123, 2, 61.5]),
#  ('Jinks/Cohen Company', [184, 3, 61.333333333333336]),
#  ('Camp / Thompson Pictures', [61, 1, 61]),
#  ('Polsky Films', [61, 1, 61]),
#  ('Miramax', [244, 4, 61.0]),
#  ('Current Entertainment', [366, 6, 61.0]),
#  ('Dee Gee Entertainment', [61, 1, 61]),
#  ('Prufrock Pictures', [61, 1, 61]),
#  ('Ixtlan Productions', [61, 1, 61]),
#  ('Global Entertainment Group', [61, 1, 61]),
#  ('Alberto Grimaldi Productions', [61, 1, 61]),
#  ('Earthship Productions', [61, 1, 61]),
#  ('Envision Entertainment', [61, 1, 61]),
#  ('Scanbox', [61, 1, 61]),
#  ('Sunset Gower Studios', [61, 1, 61]),
#  ('Ludlum Entertainment', [122, 2, 61.0]),
#  ('360 Pictures', [61, 1, 61]),
#  ('Mill Film', [61, 1, 61]),
#  ('Thunder Road Pictures', [486, 8, 60.75]),
#  ('Tribeca Productions', [364, 6, 60.666666666666664]),
#  ('Eon Productions', [182, 3, 60.666666666666664]),
#  ('Marc Platt Productions', [606, 10, 60.6]),
#  ('Wild West Picture Show Productions', [303, 5, 60.6]),
#  ('Revolution Sun Studios', [242, 4, 60.5]),
#  ('Boll Kino Beteiligungs GmbH & Co. KG', [121, 2, 60.5]),
#  ('Herold Productions', [121, 2, 60.5]),
#  ('Lin Pictures', [301, 5, 60.2]),
#  ('Walt Disney Animation Studios', [601, 10, 60.1]),
#  ('Karz Entertainment', [300, 5, 60.0]),
#  ('Zehnte Babelsberg', [60, 1, 60]),
#  ('Visiona Romantica', [60, 1, 60]),
#  ('Bernard Gayle Productions', [60, 1, 60]),
#  ('Sean S. Cunningham Films', [120, 2, 60.0]),
#  ('Crystal Lake Entertainment', [120, 2, 60.0]),
#  ('Initial Entertainment Group', [60, 1, 60]),
#  ('China Film Group Corporation (CFGC)', [120, 2, 60.0]),
#  ('Mikona Productions GmbH & Co. KG', [180, 3, 60.0]),
#  ('Sea Breeze Productions Inc.', [60, 1, 60]),
#  ('Film i VÃ¤st', [120, 2, 60.0]),
#  ('Headline Pictures', [60, 1, 60]),
#  ('Alan Greenspan Productions', [60, 1, 60]),
#  ('True Grit Productions', [60, 1, 60]),
#  ('Zero Gravity Management', [60, 1, 60]),
#  ('Pierce/Williams Entertainment', [60, 1, 60]),
#  ('Starlite Films', [60, 1, 60]),
#  ('Clifford Werber Productions', [120, 2, 60.0]),
#  ('Crystal Sky Pictures', [60, 1, 60]),
#  ('KirchMedia', [60, 1, 60]),
#  ('Sweetpea Entertainment', [60, 1, 60]),
#  ('Screen Gems', [1859, 31, 59.96774193548387]),
#  ('Signature Pictures', [179, 3, 59.666666666666664]),
#  ('Craven-Maddalena Films', [238, 4, 59.5]),
#  ('DreamWorks Animation', [1546, 26, 59.46153846153846]),
#  ('FilmNation Entertainment', [297, 5, 59.4]),
#  ('Beacon Communications', [178, 3, 59.333333333333336]),
#  ('Dylan Sellers Productions', [178, 3, 59.333333333333336]),
#  ('Saturn Films', [771, 13, 59.30769230769231]),
#  ('Rogue Pictures', [533, 9, 59.22222222222222]),
#  ('Anarchos Productions', [296, 5, 59.2]),
#  ('Vast Entertainment', [59, 1, 59]),
#  ('Fortis Films', [177, 3, 59.0]),
#  ('AZL Productions KG', [59, 1, 59]),
#  ('MFP Munich Film Partners', [59, 1, 59]),
#  ('Phase 1 Productions', [59, 1, 59]),
#  ('Marvel Knights', [118, 2, 59.0]),
#  ('Internationale Filmproduktion', [59, 1, 59]),
#  ('DJ Films', [118, 2, 59.0]),
#  ('Kumar Mobiliengesellschaft mbH & Co. Projekt Nr. 3 KG', [59, 1, 59]),
#  ('Alloy Entertainment', [59, 1, 59]),
#  ('Biscayne Pictures', [118, 2, 59.0]),
#  ('Primal Foe Productions', [59, 1, 59]),
#  ('BenderSpink', [471, 8, 58.875]),
#  ('Focus Features', [1236, 21, 58.857142857142854]),
#  ('Stuber Productions', [411, 7, 58.714285714285715]),
#  ('Disruption Entertainment', [176, 3, 58.666666666666664]),
#  ('This Is That Productions', [176, 3, 58.666666666666664]),
#  ('Laura Ziskin Productions', [293, 5, 58.6]),
#  ('Andell Entertainment', [117, 2, 58.5]),
#  ('Australian Film Finance Corporation (AFFC)', [117, 2, 58.5]),
#  ('Rat Entertainment', [234, 4, 58.5]),
#  ('Hal Lieberman Company', [117, 2, 58.5]),
#  ('2929 Productions', [350, 6, 58.333333333333336]),
#  ('Junction Entertainment', [175, 3, 58.333333333333336]),
#  ('Radiant Productions', [175, 3, 58.333333333333336]),
#  ('Silver Pictures', [989, 17, 58.1764705882353]),
#  ('Lions Gate Films', [1105, 19, 58.1578947368421]),
#  ('87Eleven', [116, 2, 58.0]),
#  ('Farah Films & Management', [58, 1, 58]),
#  ('Black and Blu Entertainment', [58, 1, 58]),
#  ('Finestkind', [58, 1, 58]),
#  ('David Brown Productions', [116, 2, 58.0]),
#  ('Achte Babelsberg Film', [58, 1, 58]),
#  ('Producers Circle', [58, 1, 58]),
#  ('Don Simpson/Jerry Bruckheimer Films', [58, 1, 58]),
#  ('City Light Films', [58, 1, 58]),
#  ('Yuma', [58, 1, 58]),
#  ('Jessie Nelson Productions', [58, 1, 58]),
#  ('Block 2 Pictures', [58, 1, 58]),
#  ('Jet Tone Production', [58, 1, 58]),
#  ('Lou Yi Inc.', [58, 1, 58]),
#  ('Munich Film Partners & Company (MFP) MI2 Productions', [58, 1, 58]),
#  ('Capella International', [58, 1, 58]),
#  ('KC Medien AG', [58, 1, 58]),
#  ('Vinyl Films', [289, 5, 57.8]),
#  ('TriStar Pictures', [980, 17, 57.64705882352941]),
#  ('Heyday Films', [691, 12, 57.583333333333336]),
#  ('Imagenation Abu Dhabi FZ', [691, 12, 57.583333333333336]),
#  ('DreamWorks SKG', [3570, 62, 57.58064516129032]),
#  ('Columbia Pictures', [6729, 117, 57.51282051282051]),
#  ('Kaplan/Perrone Entertainment', [115, 2, 57.5]),
#  ('Cheyenne Enterprises', [460, 8, 57.5]),
#  ('ApolloMedia Distribution', [115, 2, 57.5]),
#  ('Lion Rock Productions', [115, 2, 57.5]),
#  ('Revolution Studios', [1724, 30, 57.46666666666667]),
#  ('Ghost House Pictures', [516, 9, 57.333333333333336]),
#  ('Voltage Pictures', [172, 3, 57.333333333333336]),
#  ('Impact Pictures', [515, 9, 57.22222222222222]),
#  ('Walt Disney Pictures', [4687, 82, 57.15853658536585]),
#  ('De Line Pictures', [514, 9, 57.111111111111114]),
#  ('Prana Studios', [114, 2, 57.0]),
#  ('Block / Hanson', [57, 1, 57]),
#  ('One Race Productions', [285, 5, 57.0]),
#  ('Oops Doughnuts Productions', [57, 1, 57]),
#  ('Frontier Pictures', [57, 1, 57]),
#  ('Furry Vengeance Productions', [57, 1, 57]),
#  ('Alphaville Films', [342, 6, 57.0]),
#  ('Cruise-Wagner Productions', [57, 1, 57]),
#  ('Scared Productions', [57, 1, 57]),
#  ('Image Entertainment', [57, 1, 57]),
#  ('Monarch Pictures', [114, 2, 57.0]),
#  ('British Film Institute (BFI)', [114, 2, 57.0]),
#  ('Reel FX Creative Studios', [57, 1, 57]),
#  ('Patalex Productions', [57, 1, 57]),
#  ('Motion Picture BETA Produktionsgesellschaft', [57, 1, 57]),
#  ('Bourne Again', [57, 1, 57]),
#  ('Anka Film', [57, 1, 57]),
#  ('Daybreak Productions', [57, 1, 57]),
#  ('SKA Films', [57, 1, 57]),
#  ('Fat Free', [57, 1, 57]),
#  ('Walrus & Associates', [57, 1, 57]),
#  ('Hollywood Partners', [57, 1, 57]),
#  ('Charenton Productions', [57, 1, 57]),
#  ('Legendary Pictures', [1932, 34, 56.8235294117647]),
#  ('Mutual Film Company', [284, 5, 56.8]),
#  ('Franchise Pictures', [737, 13, 56.69230769230769]),
#  ('Hasbro', [283, 5, 56.6]),
#  ('Happy Madison Productions', [1300, 23, 56.52173913043478]),
#  ('Iron Horse Entertainment (II)', [113, 2, 56.5]),
#  ('John Wells Productions', [113, 2, 56.5]),
#  ('Figment Films', [113, 2, 56.5]),
#  ('Maverick Films', [282, 5, 56.4]),
#  ('Prescience', [169, 3, 56.333333333333336]),
#  ('Virtual Studios', [394, 7, 56.285714285714285]),
#  ('Everyman Pictures', [225, 4, 56.25]),
#  ('Color Force', [449, 8, 56.125]),
#  ('Genre Films', [168, 3, 56.0]),
#  ('Orange Studios', [56, 1, 56]),
#  ('CityMation', [56, 1, 56]),
#  ('On Entertainment', [56, 1, 56]),
#  ('Zippcast Films', [56, 1, 56]),
#  ('Mace Neufeld Productions', [224, 4, 56.0]),
#  ('Big Kid Pictures', [168, 3, 56.0]),
#  ('Screen Queensland', [56, 1, 56]),
#  ('Blacklab Entertainment', [56, 1, 56]),
#  ('Wolfhound Pictures', [56, 1, 56]),
#  ('Bandito Brothers', [112, 2, 56.0]),
#  ('Saga Film', [56, 1, 56]),
#  ('Chambara Pictures', [56, 1, 56]),
#  ('Polish Film Institute', [56, 1, 56]),
#  ('Exclusive Films', [56, 1, 56]),
#  ('Monolith Films', [56, 1, 56]),
#  ('On the Road', [56, 1, 56]),
#  ('Earth Canada Productions', [56, 1, 56]),
#  ('Baumgarten Management and Productions (BMP)', [56, 1, 56]),
#  ('Intrepid Pictures', [280, 5, 56.0]),
#  ('Constantin Film Ltd.', [56, 1, 56]),
#  ('Fellah Pictures', [56, 1, 56]),
#  ('Interscope Communications', [56, 1, 56]),
#  ('Polygram Filmed Entertainment', [56, 1, 56]),
#  ('Imagine Entertainment', [1398, 25, 55.92]),
#  ('Casey Silver Productions', [223, 4, 55.75]),
#  ('Spyglass Entertainment', [1783, 32, 55.71875]),
#  ('CBS Films', [557, 10, 55.7]),
#  ('Screen Australia', [167, 3, 55.666666666666664]),
#  ('Linson Entertainment', [167, 3, 55.666666666666664]),
#  ('Fox Searchlight Pictures', [1335, 24, 55.625]),
#  ('Mike Zoss Productions', [278, 5, 55.6]),
#  ('Dark Horse Entertainment', [278, 5, 55.6]),
#  ('Rogue', [111, 2, 55.5]),
#  ('USA Films', [111, 2, 55.5]),
#  ('Kopelson Entertainment', [111, 2, 55.5]),
#  ('Mediastream Vierte Film GmbH & Co. Vermarktungs KG', [111, 2, 55.5]),
#  ('TF1 Films Production', [610, 11, 55.45454545454545]),
#  ('Amblin Entertainment', [1273, 23, 55.34782608695652]),
#  ('River Road Entertainment', [332, 6, 55.333333333333336]),
#  ('Paramount Pictures', [6744, 122, 55.278688524590166]),
#  ('Marvel Studios', [663, 12, 55.25]),
#  ('Columbia Pictures Corporation', [2595, 47, 55.212765957446805]),
#  ('Trigger Street Productions', [110, 2, 55.0]),
#  ('David Dobkin Productions', [110, 2, 55.0]),
#  ('Sahara Productions', [55, 1, 55]),
#  ('Silvatar Media', [55, 1, 55]),
#  ('Universal Cartoon Studios', [55, 1, 55]),
#  ('TPS Star', [110, 2, 55.0]),
#  ('Sommers Company, The', [110, 2, 55.0]),
#  ('Europa Corp', [55, 1, 55]),
#  ('Cheetah Vision', [165, 3, 55.0]),
#  ('Loumolo & Co.', [55, 1, 55]),
#  ('Lonely Film Productions GmbH & Co. KG.', [165, 3, 55.0]),
#  ('FidÃ©litÃ© Productions', [55, 1, 55]),
#  ('Gimages', [55, 1, 55]),
#  ('FOZ', [55, 1, 55]),
#  ('Toma 78', [55, 1, 55]),
#  ('De Milo', [55, 1, 55]),
#  ('Saints LA', [55, 1, 55]),
#  ('Callahan Filmworks', [55, 1, 55]),
#  ('Storefront Pictures', [110, 2, 55.0]),
#  ('Daybreak', [55, 1, 55]),
#  ('Film Colony', [55, 1, 55]),
#  ('Loofah Productions', [55, 1, 55]),
#  ('Frantic Films', [55, 1, 55]),
#  ('Maple Shade Films', [55, 1, 55]),
#  ('Cool Music', [55, 1, 55]),
#  ('Harry Potter Publishing Rights', [55, 1, 55]),
#  ('Columbus 81 Productions', [55, 1, 55]),
#  ('Fountainbridge Films', [55, 1, 55]),
#  ('Finding Forrester Productions', [55, 1, 55]),
#  ('NPV Entertainment', [1098, 20, 54.9]),
#  ('Warner Bros. Animation', [274, 5, 54.8]),
#  ('Edward R. Pressman Film', [274, 5, 54.8]),
#  ('Vertigo Entertainment', [875, 16, 54.6875]),
#  ('Depth of Field', [164, 3, 54.666666666666664]),
#  ('Village Roadshow Pictures', [3443, 63, 54.65079365079365]),
#  ('Warner Bros.', [9173, 168, 54.601190476190474]),
#  ('Scott Rudin Productions', [1309, 24, 54.541666666666664]),
#  ('DNA Films', [545, 10, 54.5]),
#  ('Miramax Films', [2124, 39, 54.46153846153846]),
#  ('Lawrence Gordon Productions', [326, 6, 54.333333333333336]),
#  ('Endgame Entertainment', [597, 11, 54.27272727272727]),
#  ('Illumination Entertainment', [271, 5, 54.2]),
#  ('Constantin Film Produktion', [541, 10, 54.1]),
#  ('Versus Pictures', [54, 1, 54]),
#  ('Free State Pictures', [108, 2, 54.0]),
#  ('Marvel Entertainment', [324, 6, 54.0]),
#  ('Dark Castle Entertainment', [648, 12, 54.0]),
#  ('Bagdasarian Productions', [108, 2, 54.0]),
#  ('Twisted Pictures', [324, 6, 54.0]),
#  ('WWE Studios', [270, 5, 54.0]),
#  ("Butcher's Run Films", [54, 1, 54]),
#  ('Informant Media', [54, 1, 54]),
#  ('Cruise/Wagner Productions', [540, 10, 54.0]),
#  ('Sogecine', [54, 1, 54]),
#  ('Las Producciones del Escorpion', [54, 1, 54]),
#  ('Square USA', [54, 1, 54]),
#  ('ScreenWest', [54, 1, 54]),
#  ('Ghost Ship Films Pty. Ltd.', [54, 1, 54]),
#  ('Pit Bull Productions', [54, 1, 54]),
#  ('Media Asia Films', [54, 1, 54]),
#  ('Black & White Productions', [54, 1, 54]),
#  ('Fantail Films Inc.', [54, 1, 54]),
#  ('Nightfall Productions', [54, 1, 54]),
#  ('SNL Studios', [54, 1, 54]),
#  ('Jerry Bruckheimer Films', [1025, 19, 53.94736842105263]),
#  ('Moving Picture Company (MPC)', [593, 11, 53.90909090909091]),
#  ('Gary Sanchez Productions', [377, 7, 53.857142857142854]),
#  ('Offspring Entertainment', [323, 6, 53.833333333333336]),
#  ('Media Rights Capital', [752, 14, 53.714285714285715]),
#  ('Mandalay Pictures', [376, 7, 53.714285714285715]),
#  ('Metro-Goldwyn-Mayer (MGM)', [2577, 48, 53.6875]),
#  ('Universal Pictures', [9287, 173, 53.68208092485549]),
#  ('Forward Pass', [322, 6, 53.666666666666664]),
#  ('A Band Apart', [161, 3, 53.666666666666664]),
#  ('Eyetronics', [107, 2, 53.5]),
#  ('Relativity Media', [5287, 99, 53.4040404040404]),
#  ('1492 Pictures', [694, 13, 53.38461538461539]),
#  ('Art Linson Productions', [160, 3, 53.333333333333336]),
#  ('New Line Cinema', [4691, 88, 53.30681818181818]),
#  ('Stillking Films', [425, 8, 53.125]),
#  ('StudioCanal', [1221, 23, 53.08695652173913]),
#  ('Onyx Films', [106, 2, 53.0]),
#  ('Hasbro Studios', [53, 1, 53]),
#  ('Allspark Pictures', [53, 1, 53]),
#  ('Crave Films', [159, 3, 53.0]),
#  ('Outlaw Sinema', [106, 2, 53.0]),
#  ('Ghoulardi Film Company', [159, 3, 53.0]),
#  ('Mystery Clock Cinema', [53, 1, 53]),
#  ('Prospect Park', [53, 1, 53]),
#  ('Millbrook Farm Productions', [53, 1, 53]),
#  ('Aegis Film Fund', [106, 2, 53.0]),
#  ('Intellectual Properties Worldwide', [106, 2, 53.0]),
#  ('Parabolic Pictures', [53, 1, 53]),
#  ('Imhotep Productions', [53, 1, 53]),
#  ('Simon Fields Productions', [53, 1, 53]),
#  ('Cinerenta Medienbeteiligungs KG', [159, 3, 53.0]),
#  ('Hammerhead Productions', [106, 2, 53.0]),
#  ('New Wave Entertainment', [53, 1, 53]),
#  ('Terra Firma Films', [53, 1, 53]),
#  ('Superfinger Entertainment', [53, 1, 53]),
#  ('British Film Council', [53, 1, 53]),
#  ('Wessler Entertainment', [106, 2, 53.0]),
#  ('Birnbaum / Barber Productions', [106, 2, 53.0]),
#  ('N1 European Film Produktions GmbH & Co. KG', [53, 1, 53]),
#  ('Baumgarten Merims Productions', [53, 1, 53]),
#  ('Inferno International', [53, 1, 53]),
#  ('Colossal Pictures', [53, 1, 53]),
#  ('Entertainment Manufacturing Company', [53, 1, 53]),
#  ('Romero-Grunwald Productions', [53, 1, 53]),
#  ('Exception Wild Bunch', [53, 1, 53]),
#  ('Big Beach Productions', [53, 1, 53]),
#  ('Telegraph Films', [53, 1, 53]),
#  ('Senator International', [106, 2, 53.0]),
#  ('Granada Film Productions', [53, 1, 53]),
#  ('Lakeshore Entertainment', [1270, 24, 52.916666666666664]),
#  ('EuropaCorp', [899, 17, 52.88235294117647]),
#  ('DC Entertainment', [264, 5, 52.8]),
#  ('Original Film', [1531, 29, 52.793103448275865]),
#  ('Paramount Animation', [263, 5, 52.6]),
#  ('Contrafilm', [368, 7, 52.57142857142857]),
#  ('Home Box Office (HBO)', [105, 2, 52.5]),
#  ('Babelsberg Film', [105, 2, 52.5]),
#  ('Lionsgate', [1835, 35, 52.42857142857143]),
#  ('Ram Bergman Productions', [157, 3, 52.333333333333336]),
#  ('Morgan Creek Productions', [628, 12, 52.333333333333336]),
#  ('Valhalla Motion Pictures', [314, 6, 52.333333333333336]),
#  ('Studio Babelsberg', [1045, 20, 52.25]),
#  ('Sidney Kimmel Entertainment', [418, 8, 52.25]),
#  ('Sunswept Entertainment', [522, 10, 52.2]),
#  ('American Zoetrope', [261, 5, 52.2]),
#  ('Radar Pictures', [469, 9, 52.111111111111114]),
#  ('Reliance Entertainment', [416, 8, 52.0]),
#  ('Jim Henson Company, The', [52, 1, 52]),
#  ('Sketch Films', [104, 2, 52.0]),
#  ('The Halcyon Company', [52, 1, 52]),
#  ('American Empirical Pictures', [104, 2, 52.0]),
#  ('Mosaic Media Group', [520, 10, 52.0]),
#  ('Hydraulx', [52, 1, 52]),
#  ('Transmission Pictures', [52, 1, 52]),
#  ('The Saul Zaentz Company', [104, 2, 52.0]),
#  ('Pacific Data Images (PDI)', [312, 6, 52.0]),
#  ('Jonathan Krane Group', [52, 1, 52]),
#  ('Many Rivers Productions', [52, 1, 52]),
#  ('Boy of the Year', [52, 1, 52]),
#  ('Fox Searchlight', [156, 3, 52.0]),
#  ("Eric's Boy", [52, 1, 52]),
#  ('Moving Pictures', [52, 1, 52]),
#  ('Gratitude International', [52, 1, 52]),
#  ('Doom Buggy Productions', [52, 1, 52]),
#  ('XM2 Productions', [52, 1, 52]),
#  ('TF 1 Film Productions', [52, 1, 52]),
#  ('Debra Hill Productions', [52, 1, 52]),
#  ('Boll KG', [52, 1, 52]),
#  ('Industrial Development Corporation of South Africa', [52, 1, 52]),
#  ('Miracle Pictures', [52, 1, 52]),
#  ('Technical Black', [52, 1, 52]),
#  ('Run It Up Productions Inc.', [52, 1, 52]),
#  ('Robert Simonds Productions', [519, 10, 51.9]),
#  ('Blinding Edge Pictures', [415, 8, 51.875]),
#  ('Global Entertainment Productions GmbH & Company Medien KG',
#   [207, 4, 51.75]),
#  ('Colombia Pictures', [155, 3, 51.666666666666664]),
#  ('Canal Plus', [361, 7, 51.57142857142857]),
#  ('Scion Films', [567, 11, 51.54545454545455]),
#  ('Icon Entertainment International', [206, 4, 51.5]),
#  ('Emmett/Furla Films', [463, 9, 51.44444444444444]),
#  ('WingNut Films', [512, 10, 51.2]),
#  ('Temple Hill Entertainment', [408, 8, 51.0]),
#  ('Pretty Pictures', [51, 1, 51]),
#  ('ArtÃ©mis Productions', [51, 1, 51]),
#  ('Le Tax Shelter du Gouvernement FÃ©dÃ©ral de Belgique', [51, 1, 51]),
#  ('Taxshelter. be', [51, 1, 51]),
#  ('Focus Films', [204, 4, 51.0]),
#  ('Revelations Entertainment', [51, 1, 51]),
#  ('Twentieth Century Fox', [51, 1, 51]),
#  ('Fast Track Productions', [51, 1, 51]),
#  ('British Broadcasting Corporation (BBC)', [102, 2, 51.0]),
#  ('Big Talk Productions', [102, 2, 51.0]),
#  ('Dr D Studios', [51, 1, 51]),
#  ('Kennedy Miller Mitchell', [51, 1, 51]),
#  ('Newman/Tooley Films', [51, 1, 51]),
#  ('Joseph Nittolo Entertainment', [51, 1, 51]),
#  ('"DIA" Productions GmbH & Co. KG', [51, 1, 51]),
#  ('Aldrich Group', [51, 1, 51]),
#  ('Optional Pictures', [51, 1, 51]),
#  ('Halcyon Pictures', [51, 1, 51]),
#  ('Kinematograf Wien', [51, 1, 51]),
#  ('ETIC Films', [51, 1, 51]),
#  ('Arts Council of England', [51, 1, 51]),
#  ('Canal+', [1115, 22, 50.68181818181818]),
#  ('Blue Sky Studios', [456, 9, 50.666666666666664]),
#  ('Conundrum Entertainment', [304, 6, 50.666666666666664]),
#  ('Cold Spring Pictures', [152, 3, 50.666666666666664]),
#  ('Dino De Laurentiis Company', [253, 5, 50.6]),
#  ('WideAwake', [101, 2, 50.5]),
#  ('Super Cool ManChu', [101, 2, 50.5]),
#  ('C-2 Pictures', [101, 2, 50.5]),
#  ('21 Laps Entertainment', [453, 9, 50.333333333333336]),
#  ('Canadian Film or Video Production Tax Credit (CPTC)', [201, 4, 50.25]),
#  ('Avery Pix', [201, 4, 50.25]),
#  ('The Zanuck Company', [301, 6, 50.166666666666664]),
#  ('Summit Entertainment', [2051, 41, 50.02439024390244]),
#  ('Plan B Entertainment', [500, 10, 50.0]),
#  ('Watermark', [50, 1, 50]),
#  ('Kontsept Film Company', [50, 1, 50]),
#  ('Imagi Animation Studios', [100, 2, 50.0]),
#  ('Castel Film Romania', [100, 2, 50.0]),
#  ('Captivate Entertainment', [50, 1, 50]),
#  ('Transfilm', [50, 1, 50]),
#  ('Liddell Entertainment', [50, 1, 50]),
#  ('Wonderful Films PLC', [50, 1, 50]),
#  ('Mars Media Beteiligungs', [100, 2, 50.0]),
#  ('Reforma Films', [50, 1, 50]),
#  ('Mile High Productions', [50, 1, 50]),
#  ('Kevin Messick Productions', [50, 1, 50]),
#  ('Infogrames Entertainment', [50, 1, 50]),
#  ('Pacific Renaissance Pictures Ltd.', [50, 1, 50]),
#  ('Grand Slam Productions', [50, 1, 50]),
#  ('Screenland Pictures', [50, 1, 50]),
#  ('Fox Atomic', [249, 5, 49.8]),
#  ('Marvel Enterprises', [647, 13, 49.76923076923077]),
#  ('Weed Road Pictures', [348, 7, 49.714285714285715]),
#  ('CinemaNX', [99, 2, 49.5]),
#  ('New Legacy', [99, 2, 49.5]),
#  ('Appian Way', [444, 9, 49.333333333333336]),
#  ('Good Machine', [148, 3, 49.333333333333336]),
#  ('PathÃ© Renn Productions', [197, 4, 49.25]),
#  ('LivePlanet', [197, 4, 49.25]),
#  ('Twentieth Century Fox Animation', [491, 10, 49.1]),
#  ('Duperele Films', [49, 1, 49]),
#  ('Spy Next Door', [49, 1, 49]),
#  ('Toho-Towa', [196, 4, 49.0]),
#  ('Bazmark Films', [147, 3, 49.0]),
#  ('Hungarian National Film Office', [49, 1, 49]),
#  ('Lazio Film Commission', [49, 1, 49]),
#  ('Zanagar Films', [49, 1, 49]),
#  ('Mr. Mudd Production', [49, 1, 49]),
#  ('Alberta Film Entertainment', [98, 2, 49.0]),
#  ('Havana Nights LLC', [49, 1, 49]),
#  ('Friday Night Lights LLC', [49, 1, 49]),
#  ('MDBF Filmgesellschaft mbH & Company KG', [49, 1, 49]),
#  ('Foresight Unlimited', [49, 1, 49]),
#  ('RAMCO', [49, 1, 49]),
#  ('Captivity Productions', [49, 1, 49]),
#  ('Underground', [49, 1, 49]),
#  ('Flower Films (II)', [244, 5, 48.8]),
#  ('Waverly Films', [195, 4, 48.75]),
#  ('Castle Rock Entertainment', [731, 15, 48.733333333333334]),
#  ('Sony Pictures Releasing', [146, 3, 48.666666666666664]),
#  ('Firm Films', [292, 6, 48.666666666666664]),
#  ('Film Rites', [146, 3, 48.666666666666664]),
#  ('Sony Pictures', [243, 5, 48.6]),
#  ('Warner Bros. Pictures', [631, 13, 48.53846153846154]),
#  ('Malpaso Productions', [582, 12, 48.5]),
#  ('WV Films II', [97, 2, 48.5]),
#  ('Konrad Pictures', [194, 4, 48.5]),
#  ('Walt Disney Feature Animation', [339, 7, 48.42857142857143]),
#  ('Peninsula Films', [145, 3, 48.333333333333336]),
#  ('Tree Line Films', [145, 3, 48.333333333333336]),
#  ('UK Film Council', [820, 17, 48.23529411764706]),
#  ('Working Title Films', [1301, 27, 48.18518518518518]),
#  ('The Weinstein Company', [1345, 28, 48.035714285714285]),
#  ('Key Creatives', [96, 2, 48.0]),
#  ('Medienproduktion Prometheus Filmgesellschaft', [48, 1, 48]),
#  ('Portobello Studios', [48, 1, 48]),
#  ('Telecinco Cinema', [144, 3, 48.0]),
#  ('Canal+ EspaÃ±a', [192, 4, 48.0]),
#  ('Gold/Miller Productions', [144, 3, 48.0]),
#  ('Collision Entertainment', [48, 1, 48]),
#  ('Abandon Entertainment', [48, 1, 48]),
#  ('Foxtor Productions', [48, 1, 48]),
#  ('Universal Pictures Corporation', [48, 1, 48]),
#  ('Blind Wink', [48, 1, 48]),
#  ('Chrysalis Films', [48, 1, 48]),
#  ('Turner Pictures', [48, 1, 48]),
#  ('Antietam Filmworks', [48, 1, 48]),
#  ('Milkshake Films', [48, 1, 48]),
#  ('Hargitay & Hargitay Pictures in Motion', [48, 1, 48]),
#  ('Cowboy Films', [48, 1, 48]),
#  ('Atlantic Television', [48, 1, 48]),
#  ('Filmax Entertainment', [48, 1, 48]),
#  ('ICF', [48, 1, 48]),
#  ('Limited Edition Productions Inc.', [48, 1, 48]),
#  ('Barry Mendel Productions', [48, 1, 48]),
#  ('Open Road Films', [478, 10, 47.8]),
#  ('Twentieth Century Fox Film Corporation', [5205, 109, 47.75229357798165]),
#  ('Atlas Entertainment', [286, 6, 47.666666666666664]),
#  ('United Artists', [429, 9, 47.666666666666664]),
#  ('Ascendant Pictures', [143, 3, 47.666666666666664]),
#  ('Splendid Pictures', [143, 3, 47.666666666666664]),
#  ('Sony Pictures Home Entertainment', [95, 2, 47.5]),
#  ('Syncopy', [380, 8, 47.5]),
#  ('Grindstone Entertainment Group', [190, 4, 47.5]),
#  ('Montecito Picture Company, The', [190, 4, 47.5]),
#  ('Virgin Produced', [237, 5, 47.4]),
#  ('Dune Entertainment III', [805, 17, 47.35294117647059]),
#  ('International Production Company', [142, 3, 47.333333333333336]),
#  ('Misher Films', [189, 4, 47.25]),
#  ('Cruel and Unusual Films', [189, 4, 47.25]),
#  ('Province of British Columbia Production Services Tax Credit',
#   [283, 6, 47.166666666666664]),
#  ('DC Comics', [424, 9, 47.111111111111114]),
#  ('Dentsu', [565, 12, 47.083333333333336]),
#  ('A113', [47, 1, 47]),
#  ('DMG Entertainment', [141, 3, 47.0]),
#  ('Le Grisbi Productions', [47, 1, 47]),
#  ('M Productions', [47, 1, 47]),
#  ('Albert S. Ruddy Productions', [94, 2, 47.0]),
#  ('Sid & Marty Krofft Pictures', [47, 1, 47]),
#  ('Lions Gate', [94, 2, 47.0]),
#  ('Pink Machine', [47, 1, 47]),
#  ('MVL Incredible Productions', [47, 1, 47]),
#  ('Toff Guy Films', [47, 1, 47]),
#  ('Vendome Pictures', [94, 2, 47.0]),
#  ('Gambit Pictures', [47, 1, 47]),
#  ('Electric Shepherd Productions', [47, 1, 47]),
#  ('Pandora Pictures', [47, 1, 47]),
#  ('Di Bonaventura Picture', [47, 1, 47]),
#  ('Laurinfilm', [47, 1, 47]),
#  ('Subterranean Productions LLC', [47, 1, 47]),
#  ('Subterranean Productions UK Ltd.', [47, 1, 47]),
#  ('Underworld Produktions GmbH', [47, 1, 47]),
#  ('Dimension Films', [1735, 37, 46.891891891891895]),
#  ('Bel Air Entertainment', [234, 5, 46.8]),
#  ('Gunn Films', [187, 4, 46.75]),
#  ('Grosvenor Park Media Ltd.', [187, 4, 46.75]),
#  ('Zide-Perry Productions', [280, 6, 46.666666666666664]),
#  ('Touchstone Pictures', [2704, 58, 46.62068965517241]),
#  ('Davis Entertainment', [839, 18, 46.611111111111114]),
#  ('CinÃ©+', [186, 4, 46.5]),
#  ('Huayi Brothers Media', [93, 2, 46.5]),
#  ('Origin Pictures', [93, 2, 46.5]),
#  ('Overture Films', [93, 2, 46.5]),
#  ('Nu Image Entertainment GmbH', [93, 2, 46.5]),
#  ('Allied Filmmakers', [93, 2, 46.5]),
#  ('Participant Media', [697, 15, 46.46666666666667]),
#  ('Marv Films', [232, 5, 46.4]),
#  ('Mad Chance', [232, 5, 46.4]),
#  ('Wigram Productions', [139, 3, 46.333333333333336]),
#  ('Odd Lot Entertainment', [139, 3, 46.333333333333336]),
#  ('Marty Katz Productions', [139, 3, 46.333333333333336]),
#  ('Wildwood Enterprises', [185, 4, 46.25]),
#  ('Mandate Pictures', [416, 9, 46.22222222222222]),
#  ('Black Bear Pictures', [46, 1, 46]),
#  ('Bristol Automotive', [46, 1, 46]),
#  ...]

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %%
answers['26']='1. Inside Out, The Dark Knight, 12 Years a Slave' #+

per_cent=len(data)/100
data.sort_values(by='vote_average',ascending=False)[0:int(per_cent+0.5)]
# Out:
#         imdb_id     budget     revenue  \
# 599   tt0468569  185000000  1001921825
# 118   tt0816692  165000000   621752480
# 125   tt2084970   14000000   233555708
# 9     tt2096673  175000000   853708609
# 34    tt3170832    6000000    35401758
# 1183  tt0993846  100000000   392000694
# 128   tt2267998   61000000   369330363
# 1191  tt2024544   20000000   187000000
# 119   tt2015381  170000000   773312399
# 1081  tt0167260   94000000  1118888979
# 1800  tt0209144    9000000    39723096
# 370   tt1375666  160000000   825500000
# 872   tt0253474   35000000   120072577
# 138   tt2278388   30000000   174600318
# 1188  tt1798709   23000000    47351251
# 28    tt1895587   20000000    88346473
# 124   tt2245084  165000000   652105443
# 177   tt2582846   12000000   305151265
# 863   tt0167261   79000000   926287400
#
#                                      original_title  \
# 599                                 The Dark Knight
# 118                                    Interstellar
# 125                              The Imitation Game
# 9                                        Inside Out
# 34                                             Room
# 1183                        The Wolf of Wall Street
# 128                                       Gone Girl
# 1191                               12 Years a Slave
# 119                         Guardians of the Galaxy
# 1081  The Lord of the Rings: The Return of the King
# 1800                                        Memento
# 370                                       Inception
# 872                                     The Pianist
# 138                        The Grand Budapest Hotel
# 1188                                            Her
# 28                                        Spotlight
# 124                                      Big Hero 6
# 177                          The Fault in Our Stars
# 863           The Lord of the Rings: The Two Towers
#
#                                                    cast  \
# 599   Christian Bale|Michael Caine|Heath Ledger|Aaro...
# 118   Matthew McConaughey|Jessica Chastain|Anne Hath...
# 125   Benedict Cumberbatch|Keira Knightley|Matthew G...
# 9     Amy Poehler|Phyllis Smith|Richard Kind|Bill Ha...
# 34    Brie Larson|Jacob Tremblay|Joan Allen|Sean Bri...
# 1183  Leonardo DiCaprio|Jonah Hill|Margot Robbie|Kyl...
# 128   Ben Affleck|Rosamund Pike|Carrie Coon|Neil Pat...
# 1191  Chiwetel Ejiofor|Michael Fassbender|Lupita Nyo...
# 119   Chris Pratt|Zoe Saldana|Dave Bautista|Vin Dies...
# 1081  Elijah Wood|Ian McKellen|Viggo Mortensen|Liv T...
# 1800  Guy Pearce|Carrie-Anne Moss|Joe Pantoliano|Mar...
# 370   Leonardo DiCaprio|Joseph Gordon-Levitt|Ellen P...
# 872   Adrien Brody|Thomas Kretschmann|Frank Finlay|M...
# 138   Ralph Fiennes|Tony Revolori|F. Murray Abraham|...
# 1188  Joaquin Phoenix|Scarlett Johansson|Rooney Mara...
# 28    Mark Ruffalo|Michael Keaton|Rachel McAdams|Lie...
# 124   Scott Adsit|Ryan Potter|Daniel Henney|T.J. Mil...
# 177   Shailene Woodley|Ansel Elgort|Nat Wolff|Laura ...
# 863   Elijah Wood|Ian McKellen|Viggo Mortensen|Liv T...
#
#                      director  \
# 599         Christopher Nolan
# 118         Christopher Nolan
# 125             Morten Tyldum
# 9                 Pete Docter
# 34           Lenny Abrahamson
# 1183          Martin Scorsese
# 128             David Fincher
# 1191            Steve McQueen
# 119                James Gunn
# 1081            Peter Jackson
# 1800        Christopher Nolan
# 370         Christopher Nolan
# 872            Roman Polanski
# 138              Wes Anderson
# 1188              Spike Jonze
# 28               Tom McCarthy
# 124   Don Hall|Chris Williams
# 177                Josh Boone
# 863             Peter Jackson
#
#                                                 tagline  \
# 599                                     Why So Serious?
# 118   Mankind was born on Earth. It was never meant ...
# 125   The true enigma was the man who cracked the code.
# 9              Meet the little voices inside your head.
# 34                             Love knows no boundaries
# 1183                                EARN. SPEND. PARTY.
# 128         You don't know what you've got 'til it's...
# 1191    The extraordinary true story of Solomon Northup
# 119                         All heroes start somewhere.
# 1081                    The eye of the enemy is moving.
# 1800                  Some memories are best forgotten.
# 370                Your mind is the scene of the crime.
# 872   Music was his passion. Survival was his master...
# 138             A perfect holiday without leaving home.
# 1188                           A Spike Jonze Love Story
# 28                  Break the story. Break the silence.
# 124      From the creators of Wreck-it Ralph and Frozen
# 177                                 One Sick Love Story
# 863                              A New Power Is Rising.
#
#                                                overview  runtime  \
# 599   Batman raises the stakes in his war on crime. ...      152
# 118   Interstellar chronicles the adventures of a gr...      169
# 125   Based on the real life story of legendary cryp...      113
# 9     Growing up can be a bumpy road, and it's no ex...       94
# 34    Jack is a young boy of 5 years old who has liv...      117
# 1183  A New York stockbroker refuses to cooperate in...      180
# 128   With his wife's disappearance having become th...      145
# 1191  In the pre-Civil War United States, Solomon No...      134
# 119   Light years from Earth, 26 years after being a...      121
# 1081  Aragorn is revealed as the heir to the ancient...      201
# 1800  Suffering short-term memory loss after a head ...      113
# 370   Cobb, a skilled thief who commits corporate es...      148
# 872   The Pianist is a film adapted from the biograp...      150
# 138   The Grand Budapest Hotel tells of a legendary ...       99
# 1188  In the not so distant future, Theodore, a lone...      126
# 28    The true story of how The Boston Globe uncover...      128
# 124   The special bond that develops between plus-si...      102
# 177   Despite the tumor-shrinking medical miracle th...      125
# 863   Frodo and Sam are trekking to Mordor to destro...      179
#
#                                                  genres  \
# 599                         Drama|Action|Crime|Thriller
# 118                     Adventure|Drama|Science Fiction
# 125                          History|Drama|Thriller|War
# 9                               Comedy|Animation|Family
# 34                                       Drama|Thriller
# 1183                                 Crime|Drama|Comedy
# 128                              Mystery|Thriller|Drama
# 1191                                      Drama|History
# 119                    Action|Science Fiction|Adventure
# 1081                           Adventure|Fantasy|Action
# 1800                                   Mystery|Thriller
# 370   Action|Thriller|Science Fiction|Mystery|Adventure
# 872                                           Drama|War
# 138                                        Comedy|Drama
# 1188                      Romance|Science Fiction|Drama
# 28                               Drama|Thriller|History
# 124            Adventure|Family|Animation|Action|Comedy
# 177                                       Romance|Drama
# 863                            Adventure|Fantasy|Action
#
#                                    production_companies release_date  \
# 599   DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
# 118   Paramount Pictures|Legendary Pictures|Warner B...    11/5/2014
# 125              Black Bear Pictures|Bristol Automotive   11/14/2014
# 9     Walt Disney Pictures|Pixar Animation Studios|W...     6/9/2015
# 34    Element Pictures|No Trace Camping|A24|Duperele...   10/16/2015
# 1183  Paramount Pictures|Appian Way|EMJAG Production...   12/25/2013
# 128   Twentieth Century Fox Film Corporation|Regency...    10/1/2014
# 1191  Plan B Entertainment|Regency Enterprises|River...   10/18/2013
# 119   Marvel Studios|Moving Picture Company (MPC)|Bu...    7/30/2014
# 1081                      WingNut Films|New Line Cinema    12/1/2003
# 1800  Summit Entertainment|Newmarket Capital Group|T...   10/11/2000
# 370             Legendary Pictures|Warner Bros.|Syncopy    7/14/2010
# 872   Bac Films|Canal+Polska|Heritage Films|Studio B...    9/24/2002
# 138   Fox Searchlight Pictures|Scott Rudin Productio...    2/26/2014
# 1188                                 Annapurna Pictures   12/18/2013
# 28    Participant Media|Open Road Films|Anonymous Co...    11/6/2015
# 124   Walt Disney Pictures|Walt Disney Animation Stu...   10/24/2014
# 177   Fox 2000 Pictures|Temple Hill Entertainment|TS...    5/16/2014
# 863   WingNut Films|New Line Cinema|The Saul Zaentz ...   12/18/2002
#
#       vote_average  release_year      profit  month  title_length  \
# 599            8.1          2008   816921825      7            15
# 118            8.0          2014   456752480     11            12
# 125            8.0          2014   219555708     11            18
# 9              8.0          2015   678708609      6            10
# 34             8.0          2015    29401758     10             4
# 1183           7.9          2013   292000694     12            23
# 128            7.9          2014   308330363     10             9
# 1191           7.9          2013   167000000     10            16
# 119            7.9          2014   603312399      7            23
# 1081           7.9          2003  1024888979     12            45
# 1800           7.9          2000    30723096     10             7
# 370            7.9          2010   665500000      7             9
# 872            7.9          2002    85072577      9            11
# 138            7.9          2014   144600318      2            24
# 1188           7.8          2013    24351251     12             3
# 28             7.8          2015    68346473     11             9
# 124            7.8          2014   487105443     10            10
# 177            7.8          2014   293151265      5            22
# 863            7.8          2002   847287400     12            37
#
#       words_overview
# 599               67
# 118               35
# 125               46
# 9                112
# 34                49
# 1183              29
# 128               30
# 1191              61
# 119               28
# 1081              45
# 1800              78
# 370               44
# 872               39
# 138               66
# 1188              65
# 28                30
# 124               29
# 177               47
# 863               41

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %%
answers['27']='5. Daniel Radcliffe & Rupert Grint' #+

import itertools
m_temp = [] 
for cast in data.cast.str.split('|'):
    m_temp.extend(sorted(list(itertools.combinations(cast, 2)))) # сохраняем парные комбинации
# Без sorted результат тот же, но это попытка избежать  (Daniel Radcliffe, Emma Watson) и (Emma Watson, Daniel Radcliffe)
# ввиду того, что в data  актеры могут распологаться не в алфавитном порядке
pairs = pd.Series(m_temp).value_counts()
pairs
# Out:
# (Daniel Radcliffe, Emma Watson)        8
# (Daniel Radcliffe, Rupert Grint)       8
# (Rupert Grint, Emma Watson)            7
# (Johnny Depp, Helena Bonham Carter)    6
# (Ben Stiller, Owen Wilson)             6
#                                       ..
# (Meryl Streep, Marin Ireland)          1
# (Kuno Becker, Gary Lewis)              1
# (RenÃ©e Zellweger, Richard Jenkins)    1
# (Miles Teller, Sarah Wright)           1
# (Robin Williams, Seth Green)           1
# Length: 18121, dtype: int64

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': '5. Pirates of the Caribbean: On Stranger Tides (tt1298650)',
#  '2': '2. Gods and Generals (tt0279111)',
#  '3': '3. Winnie the Pooh (tt1449283)',
#  '4': '2. 110',
#  '5': '1. 107',
#  '6': '5. Avatar (tt0499549)',
#  '7': '5. The Lone Ranger (tt1210819)',
#  '8': '1. 1478',
#  '9': '4. The Dark Knight (tt0468569)',
#  '10': '5. The Lone Ranger (tt1210819)',
#  '11': '3. Drama',
#  '12': '1. Drama',
#  '13': '5. Peter Jackson',
#  '14': '3. Robert Rodriguez',
#  '15': '3. Chris Hemsworth',
#  '16': '3. Matt Damon',
#  '17': '2. Action',
#  '18': '1. K-19: The Widowmaker (tt0267626)',
#  '19': '5. 2015',
#  '20': '1. 2014',
#  '21': '4. Сентябрь',
#  '22': '2. 450',
#  '23': '5. Peter Jackson',
#  '24': '5. Four By Two Productions',
#  '25': '3. Midnight Picture Show',
#  '26': '1. Inside Out, The Dark Knight, 12 Years a Slave',
#  '27': '5. Daniel Radcliffe & Rupert Grint'}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
# Out:
# 27
